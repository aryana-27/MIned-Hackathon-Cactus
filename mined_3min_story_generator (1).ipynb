# %%
import os
import textwrap
import re
import google.generativeai as genai

# ✅ Set Gemini API Key Securely
os.environ["GEMINI_API_KEY"] = "YOUR GEMINI API KEY"  # Replace with your actual API key
GEN_API_KEY = os.getenv("GEMINI_API_KEY")
if not GEN_API_KEY:
    raise ValueError("❌ Error: Missing Gemini API Key! Set it using os.environ['GEMINI_API_KEY'] = 'YOUR_KEY'")

genai.configure(api_key=GEN_API_KEY)

# Function to split text into chunks
def split_text(text, max_chunk_size=800):
    return textwrap.wrap(text, width=max_chunk_size, break_long_words=False, replace_whitespace=False)

# 📌 Function to generate a **concise 3-minute storyboard script** with 5-second timestamps
def generate_3min_storyboard_with_timestamps(text):
    try:
        model = genai.GenerativeModel("gemini-pro")
        prompt = f"""
        You are an expert in creating engaging, structured, and visually detailed **video storyboard scripts**.
        Your task is to **summarize the provided research into a structured, cinematic storyboard (~3 minutes total length, ~180 seconds)**.

        **📌 Requirements:**
        - **Concise and structured** like the example (Diabetes Detection storyboard).
        - Use **clear scene breakdowns** (e.g., "Scene 1 (0-5s): [Visuals] + [Audio]").
        - **Divide each scene into 5-second intervals**.
        - **6-7 scenes covering 3 minutes** (each scene will be broken into 5-second chunks).
        - Focus on **visual storytelling**, **smooth transitions**, and **clear narration**.
        - **Keep it engaging**, avoiding overly technical language.
        - Provide an **impactful call to action** at the end.

        **📜 Example Storyboard Format with 5-second timestamps:**
        ```
        **Scene 1 (0-5 seconds)**
        - **Visual:** [Describe first 5-second shot]
        - **Audio:** [Narration that introduces the topic concisely]

        **Scene 1 (5-10 seconds)**
        - **Visual:** [Continue next 5-second shot]
        - **Audio:** [Continue narration]

        **Scene 2 (30-35 seconds)**
        - **Visual:** [Describe how to introduce the problem]
        - **Audio:** [Briefly explain why the problem matters]
        ...
        ```
        Now, generate a similar **3-minute storyboard with 5-second timestamps** for the following research text:
        **Research Text:** {text}
        """

        response = model.generate_content(prompt)
        if response and response.text:
            print("✅ 3-Minute Storyboard with Timestamps generated successfully.")
            return response.text
        else:
            print("❌ Error: Empty response from Gemini API.")
            return None

    except Exception as e:
        print(f"❌ Error generating storyboard: {e}")
        return None

# Extract references to tables, figures, and equations
def extract_references(text):
    ref_pattern = r"(Table|Figure|Equation|Fig|Eq)\s?\d+"
    references = re.findall(ref_pattern, text)
    return list(set(references))  # Remove duplicates

# Function to process research paper text and generate a 3-minute storyboard with 5-second timestamps
def process_research_paper_with_timestamps(text):
    chunks = split_text(text, max_chunk_size=800)
    full_storyboard = ""
    all_references = set()

    for i, chunk in enumerate(chunks):
        print(f"\n🔹 Processing Chunk {i+1}/{len(chunks)}...\n")
        references = extract_references(chunk)

        storyboard = generate_3min_storyboard_with_timestamps(chunk)  # Generate 3-minute storyboard with 5-second timestamps

        if storyboard:
            print("\n🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**\n")
            print(storyboard)
            full_storyboard += "\n" + storyboard

        print("\n🔷 References Detected:", references)
        all_references.update(references)

    return full_storyboard, all_references

# Example: Research paper text (Replace with actual text)
research_paper = """
4thMediterranean Conference on Embedded ComputingMECO - 2015Budva, Montenegro

An Intelligent System  for Diabetes Prediction

Zhilbert Tafa
Dep. of  Computer Science
University for Business and Technology
Prishtina, Kosovo
tafaul@t -com.me
 Nerxhivane Pervet ica
Bertran Karahoda
Dep. of Computer Science
University for Business and Technology
Prishtina, Kosovo
np32972@ubt -uni.net
b.karahoda@ubt -uni.net


Abstract—With the emerging increase of diabetes, that recently
affects around 346 million people, of which more than one-third
go undetected in early stage, a strong need for supporting the
medical deci sion-making process  is generated . A number of
researches have focused either in using one of the algorithms or
in the comparisons of the performances of algorithms on a given,
usual ly predefined and static datasets that are accessible through
the Internet.  This paper focuses on the joint implementation of
the support vector machine (SVM) and N aïve Bayes statistical
modeling , in the dataset acquired from the medical examinations
of 40 2 patients , in order to improve the computer -supported
diagnosis reliability . The dataset contains some attributes that
have not been previously used in computer -based evaluations .
The results show that the joint implementation of two algorithms
improves s ignificantly the overall reliability  of the system
outcome , which is crucial in the computer -supported diabetes
diagnostic process .
Keywords - algorithms;  diabetes ; joint implementation,  machine
learning ; Naïve Bayes ; support vector machine .
I.  INTRODUCTION
Diabetes is a chronic disease caused by the increase in
blood sugar , mainly either due to the less production or no
production of insulin in body ( type 1 diabetes ), or due to  the
fact that cells do not respond to the produced insulin  (type 2
diabetes) . In recent years, the number of diabetic patients has
increased drastically , as noted in [1],  mainly due to the aging
population and  irregular western food habits . According to the
World Health Organization , diabetes affects around 346
million people in the wo rld, with the prevalence of diabetes
type 2. Moreover, diabetes is the major cause for heart stroke,
kidney failure, lower -limb amputations and blindness. As
presented in [2 ], the absence of symptoms, or the absence of
recognition of the indicators in the patient’s data , may lead to
the pre -diabetes or diabetes condition that go es undetected
even in more than one-third of people that ar e later diagnosed
with diabetes.
During the clinical examinations of various forms, lots of
data are acquired from patients. The development of the
computer -based methods that would enable the high
probability recognition of pre -diabetic or diabetic condition can
be an efficient support t o the decision making in healthcare.  Machine learning is  the area of artifici al intelligence  that
uses the statistical analyse s, and is recognized to be a
promising area that, based on the given dataset of diabetics,  can
help in patient classification or probability prediction regarding
the patient’s pre-diabetic or diabetic condition.  The main
strength of these methods is contained in the ability of the
algorithms to learn from data and to use that knowledge for
later predictions and decisions. There are a number of machine
learning and statistical modeling approaches that so far have
been involved in various aspects of solving the problem .
According to [3 ], although other classifiers perform well, the
SVM outperforms other  classifiers with respect to accuracy,
sensitivity, specificity , and precision.
This paper presents a  joint Matlab implementation of the
SVM and N aïve Bayes methods in a new dataset acquired from
the patients examined for diabetes in Kosovo. The developed
diagnostic tool enables the in telligent computer -based
prediction on diabetes , based on the previously acquired
values. The statistical analysis shows the high accuracy of data
classification.  Also, the proposed joint implementation of two
algorithms aims to improve the  reliability of the decision by
using the power of both algorithms in minimizing their
individual weakness .
The rest of the paper is structured as follows. Related work
on the topic is presented in Section II . In section III, the
experimental  setup and the  implementation are  presented.
Results are shown and discussed in Section IV  while the
Section V concludes the work .
II. RELATED WORK
A number of research efforts  have  been directed in
involving the machine learning algorithms to the design of
intelligent healthcare applications,  especially in disease
detection.  Most of them have focused on heart disease, cancer
detection, and diabetes.  An analytical study of several
algorithms , focused on classification of d iabetes mellit us data ,
is presented in [1 ]. The algorithms have mostly  focused on
detection of pre -diabetes, which was recognized in [4 ] as a
relatively strong  indication for the future development of
diabetes. A recent study in this direction is given in [5 ], where
two machine learning techniques, namely SVM and ANN

4thMediterranean Conference on Embedded ComputingMECO - 2015Budva, Montenegro

(Artificia l Neural Networks) , are used to predict pre -diabetes
in Korean population.  A similar approach is used in studying
the correlation for hematological parameters and glucose level
for identification of diabetes  [6].
In general, the research focus is to conduc t some of the
supervised learning  algorithms on the given dataset and
extract the knowledge about the prediction of diabetes based
on given values of the appropriate attributes. In [7], the SVM
implementation gives the prediction accuracy of 94 %. Another
implementation of the SVM in detec ting the diabetes is given
in [8 ]. Here, t he SVM classifier , however , performs only 78 %
of accuracy . A method for prediction of diabetes by using
Bayesian network is given in [9 ] while the authors in [10]
separately use Naïve Bayes and k -nearest neighbor algorithm.
Most of the mentioned researches , rely on Pima Indian
database of diabetic, and therefore have the same attributes
and similar conclusions. Furthermore, they treat one or two
algorithms independently to compar e the efficiency of the
algorithms between each other.  Some studies, however,
recommend the hybrid use of a distance -based algorithm and a
statistical based method [11] or the combination of
classification and clustering [1].
In contrast to the most of the  mentioned materials and
methodologies,  this paper treats original dataset , with different
attributes,  extracted from the medical examinations in Kosovo.
Beside the algorithm performance evaluations, t he aim of the
paper  is not only to analyze the dataset and to provide a
supporting tool for diabetes detection, but also to improve the
derived decision reliability  by jointly using two machine
learning algorithms . This creates a more reliable zone (with
the answers yes/no on diabetes) and a “grey zone” that would
direct the decision making process to the further clinical
examinations.
III. MATERIALS AND IMPLEMENTATION METHODS
A. Dataset description
Dataset consists of 402 instances  taken from three different
locations in Kosovo. During the data a cquisition process, the
appropriate importance is given to the patient’s data privacy
and anonymity.  The attributes of the database are : BMI (body
mass index), glucose level before meal and after meal, the
systolic and diastolic blood pressure, the heredit arily factor, the
regular diet, and daily physical activities. The last two
attributes are evaluated as follows. Regarding the issue of
regular diet,  while relying on inputs from the medical
clinicians,  patients  were asked if they took  their meals in
appro ximately same equidistant daily intervals at least three
times a day and also if their meals were  not voluminous. With
these answers being positive , we consider  that a patient is
having  the regular diet. On the other hand , according to the
U.S. Center  for Disease Control and Prevention (CDCP), the
adult person  is considered to be physically active if he/she
conducts the 150 -200 min of physical activities a week.  With
the answers on the family history questions, and i n accordance
to the above given threshold s, the answers of the examinee regarding the  last three questions are mapped into two values: 1
and 0.
The range s of the values  of all attributes  are given in Table I.
TABLE I.  THE RANGES OF THE ATTRIBUTES
Attribute  Value range
From  To
BMI  15 40
Pre meal glucose  3.5 19
Post meal glucose  4.9 22.8
Diastolic blood pressure  55 110
Systolic blood pressure  90 200
Family history of diabetes  No (0)  Yes (1)
Regular diet  No (0)  Yes (1)
Physical activities  No (0)  Yes (1)

After acquiring the given initial data from patients, and
after the extensive laboratory examinations and continuous
monitoring, 80 of patie nts were diagnosed with type 2
Diabetes. The presence of diabetes i n an instance was labeled
with B oolean 1. The rest of patients were not diagnosed with
diabetes , which results in  number of 322 Boolean zeros in the
dataset .
B.  The SVM implementation
The SVM algorithm represents the instances as points in
space, mapped so that separate classes are divided by a clear
gap. The aim is to find the maximum -margin hyper plane – the
one that gives the greatest separation between the classes. The
instances that are closest to the maximum -margin hyper plane
are called support vectors. Support vectors are chosen based on
the po rtion of the dataset that represents the training set.
Support vectors of two classes enable the creation of two
parallel hyper planes. The larger the margin between these two
hyper planes, the better the generalization error of the
classifier.
Training d ata points can be represented in form:
{(X1, Y1), (X2, Y2)…., (Xn, Yn)}

where Xi is a k -dimensional vector and Yi is +1 or -1
denoting the class to which a given point belongs to.
The training data is then divided by a hyper plane of general
form:
𝑊∗𝑋+𝐵=0              (1)
Where W is k -dimensional vector, perpendicular to the hyper
plain and B is scalar. Two parallel hyper planes that belong to
two different classes can be described by equations:

4thMediterranean Conference on Embedded ComputingMECO - 2015Budva, Montenegro

𝑊∗𝑋+𝐵=1           (2)
𝑊∗𝑋+𝐵=−1           (3)
The distance between the hyper planes is 2/|W| so the aim
is to minimize |W|. The semantics behind the
multid imensional formulations  (1)-(3) is given in [12 ] and
further process of minimization of factor 2/|W| is explained in
[13].
C. The N aïve Bayes implementation
The N aïve Bayes classification is based on the probabilistic
Bayes theory. As noted in [11 ], the N aïve Bayes statistical
algorithm is a frequently used method in prediction problem.
The implementation of the statistical modeling is based on
linear function. T heoretically , it usually  means the appliance
of unrealistic assumption that the attributes are equally
important and independent. Th e real life dataset consists  of
attributes that are certainly not equally important or
indep endent, but, a s noted in [12 ] and also shown in this
paper, it leads to a simple scheme that, again, works
surpri singly well in practice.
While keeping in mind the above mentioned independency
assumption, the calculation of the probability tha t a given
record belongs t o class Y=C, can be calculated as the product
of probability that each of value s of the i record’s attributes
belong to class C, i.e.,

𝑃 𝑋 𝑌=𝐶 =  𝑃(𝑞
𝑖=1𝑋𝑖 𝑌=𝐶                                      (4)
The probability that a given value of the attribute belongs
to class 𝑦𝑗, when the dataset contains numerical inputs, can
often generally be calculated by using the Gaussian
distribution function, i.e.,
𝑃 𝑋𝑖=𝑥𝑖 𝑌=𝑦𝑗 =1
 2𝜋𝜎𝑖𝑗𝑒− 𝑥𝑖−𝜇𝑖𝑗 2
2𝜎𝑖𝑗2                               (5)

Finally, the probability that a given record will be classified in
class C, can be formulated with:

𝑃 𝐶 𝑥1,…𝑥𝑛 =𝑃 𝐶 𝑃 𝑥1,…,𝑥𝑛 𝐶
𝑃 𝑥1,…𝑥𝑛                                            (6)
D. The proposed architecture
The system consists of the following elements. Two
machines, namely SVM and Naïve Bayes classifier , build their
classifiers based on the training sets. Afterward, they are ready
to perform the classification of a given record. The output can
belong to one of two classes: class 0 (no diabetes) and class 1
(diabetes). If the outcomes from both classifiers are equal, the
record is classified as belonging to class 0 or class 1. If the
output is different, then the record is considered as still
unclassified (gre y zone).
The SVM algorithm is  implement ed by using
bioinformatics tool  in Matlab  while Naïve Bayes implementation is constructed manually, also in Matlab .
Matlab was  chosen due to its flexibility and ability to work
with various file formats. By using the  Matlab function, the
data are divided into  the training set and the testing set . The
classifier is extracted from the training set while the instances
from the testing set are tested on the derived classifier. The
SVM algorithm uses the polynomial kernel.  In order to
mitigate any bias caused by samples chosen for holdout, the
repeated holdout method  of error estimation is used. In this
direction, the process of classifier performance evaluation is
repeated 100 times with the classifier performance evaluate d
in each of the iteration.
IV. RESULTS  AND DISCUSSIONS
Prior to building the application, analyzing data, and
evaluating the classification performance, sample size is
conducted to analysis in accordance to the methodology
described in [14]. With the given nu mber of population, the
given response distribution of  diabetes in Kosovo, and  the
given confidence level of 98%, the margin of error that occurs
due to the limited number of examinee is expected to be in the
range of 1,62 %.
The developed  Matlab -based application works in two
modes: the assessment mode and the data acquisition mode.
The GUI is given in Fig. 1 .

Fig. 1: Diabetes diagnostic a pplication GUI
The data acquisition  mode enables for the addition of new
records, in order to increas e the sample size and the
classification accuracy. The  assessment mode gives the
prediction of pre -diabetic or diabetic condition on each of the
newly added record.
The prediction on new record is based on the execution of
both SVM and Naïve Bayes classifi cation  on previous
instances with different randomly chosen training sets . If both
classifiers classify the record as being positive or negative, then
we consider the given output of the classifier for a specific
record as having high reliability . Otherwis e, if the outputs  are
different , the patient needs to be further monitored on diabetes.
For the simplicity reasons, by incorporating the
stratification, the data are quasi -randomly split into  two equal
sets - 201 instances for training and 201 instances f or
evaluating the performances . In general, these two sets are only
approximately equal, since  the number s of instances  for


4thMediterranean Conference on Embedded ComputingMECO - 2015Budva, Montenegro

training and testing are  selected automatically by crossvalind
Matlab function. In order to find the average value of the
classifier s’ accuracy , the process of random selection of the
training set and test set  along with the classifier performance
evaluation on each random selection is repeated 100  times .
The results show the mean value of the SVM classifier
performance  - accuracy  of 95, 52 % while for the Naïve Bayes
classifier  the classifier accuracy is 94,  52%. Both values vary
in +/- 1% of classification performance margin during various
iterations.  This also shows for the high stability of classifier.
The average number  of correctly and incorrectly classified
records is calculated  for both classifiers and the results are
given in Table II  along with the structure of the sample
distribution for training and testing the system .
TABLE II.  CLASSIFICATION AND THE AVERAGE ACCURACY
 No. of
record s Train set
/ test set  No. of
correctly
classified  No. of
incorrectly
classified
records  Classifier
performance
(mean value)
SVM  402 201/201  192 9 95.52%
Naïve
Bayes  402 201/201  190 11 94.53 %

As can be noted, and as expected, in terms of the overall
average classification accuracy, SVM over performs the Naïve
Bayes classification, but the difference in classifier
performance is surprisingly small.
The performances are also estimated in terms of other
multi -class classification  measures such as precision and
recall. For a specific class, these two measures are calculated
as follows:

𝑃𝑟𝑒𝑐𝑖𝑠𝑖𝑜𝑛𝑋=𝑇𝑃𝑋
𝑇𝑃𝑋+𝐹𝑃𝑋           (7)

𝑅𝑒𝑐𝑎𝑙𝑙𝑋=𝑇𝑃𝑋
𝑇𝑃𝑋+𝐹𝑁𝑋                         (8)

The notations TP, FP and FN refer to the number of data
classified as true positive, false positive and false negative,
i.e., the data correctly classified in class X, the data that
belong to another class and are incorrectly classified in class
X, and the  data that should have been classified in class X
whereas are classified in another class..
The results regarding the precision and recall of classes
YES and NO are given in Table III.
TABLE III.  PRECISION AND RECALL
 Precision
(Class NO)  Recall
(ClassNO)  Precision
(Class YES)  Recall
(Class YES)
SVM  0.97 0.975  0.892  0.868
Naïve
Bayes  0.981  0.951  0.814  0.921

The joint implementation aims to improve the reliability of
the decision in case when both algorithms give the same outcome, when we consider the outcome to be valid.
Otherwise, when the outcomes are different, we consider the
decision to be unreliable and hence invalid.
After the repeated joint implementation of both algorithms,
the average rate of the valid outcomes turns out to be 94, 77 %
with the expected lower bound of approximately 90, 3 %. This
means that the major number (94, 77%) of new patients that
need to be classified regarding the likeness of diabetic
condition, will be classified the same way by two inde pendent
classifiers. The difference of 5.23 % in the results of
classifiers exists due to their individual weaknesses and can
also be related to the dataset. Among the valid  outcomes, the
derived accuracy of the dec ision is now improved up to 97,6
%, which  significantly over performs both classifiers
individually.
V. CONCLUSIONS AND FUTUR E WORK
The research efforts presented in this paper are focused in
developing and the evaluation of a computer -based support tool
for the diabetes  detection .
The presented approach is based on the joint
implementation of two algorithms in Matlab that have been
executed on the newly acquired dataset with the different
attributes as compared to the previous work in this field . The
algorithms are executed and eval uated independently but the
decision making is based on the joint outcomes from both
algorithms.  The aim of this approach is to make the decision
more reliable.
As shown in the paper, both SVM and naïve Bayes
algorithm have individually shown high overall classifier
performances  of 95 , 52% and 94, 52%, respectively.  The joint
implementation on the same, newly added record leads to one
of the three answers: a) the patient is diagnosed with diabetes
(or pre -diabetic condition), b) the patient is not d iagnosed as
having the mentioned condition, and c) the patient is further
directed to the additional clinical examinations.  If two
algorithms show different results, the answer is classified as
condition c). Otherwise, the accuracy of the answers a) or  b) ,
as shown in the paper, is improve d up to the value of 97,6%.
The presented methodology minimizes the false negative
answers, which is a crucial issue in medical diagnoses.
Finally, the construction approach, the architecture, and the
evaluation of a diab etes classification tool presented in this
paper, should provide an important guideline to further
construction of the similar applications on improving and
helping the decision making process in disease detection.  The
development of a user -friendly and wi dely accessible
application would enable the personal self -screening on
diabetic or pre -diabetic condition which is crucial to the disease
treatment performance.
The future work will focus on further quantitative
evaluation s of the developed tool  regarding the extensive
clinical examinations and results . Also, other methods should
be involved in finding the best fit in the sense of accuracy,
processing time, etc. The influence of cultural -related biases
(such as those related to the nutrition struc ture and habits)
"""

# Run the processing function
final_storyboard, detected_references = process_research_paper_with_timestamps(research_paper)

# Print results
print("\n🎬 **Final 3-Minute Storyboard with 5-Second Timestamps:**\n")
print(final_storyboard)

if detected_references:
    print("\n📌 References Detected:\n")
    print(", ".join(detected_references))
# Out:
# 🔹 Processing Chunk 1/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Opening shot of a montage of people living with diabetes, showcasing the impact on their lives.
# - **Audio:** "Diabetes affects millions worldwide, with many cases going undetected."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Close-up of a person checking their blood sugar levels.
# - **Audio:** "Early detection is crucial for effective management."
#
# **Scene 1 (10-15 seconds)**
# - **Visual:** Animated data visualization displaying the prevalence of diabetes globally.
# - **Audio:** "Existing methods for detection have limitations in accuracy and timeliness."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Transition to a laboratory setting, where researchers are developing an intelligent diabetes prediction system.
# - **Audio:** "Our system aims to bridge this gap by providing early, accurate detection."
#
# **Scene 2 (20-25 seconds)**
# - **Visual:** Animated flow diagram explaining the system's data processing and analysis.
# - **Audio:** "It leverages machine learning algorithms and predictive analytics."
#
# **Scene 3 (25-30 seconds)**
# - **Visual:** Demonstration of the system's easy-to-use interface for healthcare professionals.
# - **Audio:** "Empowering healthcare professionals with accessible, efficient tools."
#
# **Scene 3 (30-35 seconds)**
# - **Visual:** Return to shots of people living with diabetes, now accompanied by the system's detection results.
# - **Audio:** "Our system enables timely interventions, improving outcomes for patients."
#
# **Scene 4 (35-40 seconds)**
# - **Visual:** Charts and graphs displaying the system's accuracy and reliability in detecting diabetes.
# - **Audio:** "Clinical studies have proven its effectiveness in identifying high-risk individuals."
#
# **Scene 4 (40-45 seconds)**
# - **Visual:** A group of healthcare professionals discussing the system's potential impact on patient care.
# - **Audio:** "This tool empowers us to make informed decisions, leading to better health outcomes."
#
# **Scene 5 (45-50 seconds)**
# - **Visual:** Montage of individuals taking proactive steps to manage their health, guided by the system's insights.
# - **Audio:** "Our system enhances patient self-management and empowers individuals to take control."
#
# **Scene 6 (50-55 seconds)**
# - **Visual:** A wider perspective, showcasing the global reach and impact of the intelligent diabetes prediction system.
# - **Audio:** "Together, we're revolutionizing diabetes management, one step at a time."
#
# **Call to Action (55-60 seconds)**
# - **Visual:** Logo of the research institution or organization supporting the system.
# - **Audio:** "Join us in the fight against diabetes. Share, support, and let's make early detection a reality for all."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 2/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Diabetes Detection Storyboard**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Introductory shot of a medical clinic.
# - **Audio:** Narrator introduces the challenge of diagnosing diabetes.
#
# **Scene 2 (5-10 seconds)**
# - **Visual:** Close-up of a patient undergoing a medical examination.
# - **Audio:** Narrator explains the importance of accurate diagnosis.
#
# **Scene 3 (10-15 seconds)**
# - **Visual:** Laboratory equipment analyzing blood samples.
# - **Audio:** Narrator discusses the need to improve diagnostic methods.
#
# **Scene 4 (15-20 seconds)**
# - **Visual:** Statistical model and data analysis charts.
# - **Audio:** Narrator introduces the use of advanced algorithms.
#
# **Scene 5 (20-25 seconds)**
# - **Visual:** Side-by-side comparison of SVM and Naive Bayes models.
# - **Audio:** Narrator explains the joint implementation of the algorithms.
#
# **Scene 6 (25-30 seconds)**
# - **Visual:** Patient data being processed by the combined algorithm.
# - **Audio:** Narrator highlights the improved reliability of the diagnostic system.
#
# **Scene 7 (30-35 seconds)**
# - **Visual:** Close-up of a doctor reviewing the enhanced diagnostic results.
# - **Audio:** Narrator emphasizes the impact of improved diagnosis on patient outcomes.
#
# **Call to Action (35 seconds)**
# - **Visual:** Montage of healthcare professionals and patients.
# - **Audio:** Narrator urges viewers to support research and innovation in medical technology to enhance diabetes diagnosis and patient care.
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 3/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Close-up of a blood test strip with elevated blood sugar levels
# - **Audio:** *Narrator:* "Diabetes, a prevalent and life-threatening condition..."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Animated diagram showing the pancreas producing and releasing insulin
# - **Audio:** *Narrator:* "...characterized by the body's inability to regulate blood sugar."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Montage of people with diabetes managing their symptoms and receiving treatment
# - **Audio:** *Narrator:* "From insulin injections to lifestyle modifications, managing diabetes is crucial."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Scientists using advanced technologies to analyze data
# - **Audio:** *Narrator:* "Research and innovation are key to addressing the diabetes epidemic."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** Computer simulation of a support vector machine (SVM) algorithm
# - **Audio:** *Narrator:* "Support vector machines, a powerful machine learning technique..."
#
# **Scene 3 (25-30 seconds)**
# - **Visual:** SVM algorithm identifying patterns in diabetes patient data
# - **Audio:** *Narrator:* "...can enhance our ability to detect and manage diabetes."
#
# **Scene 4 (30-35 seconds)**
# - **Visual:** Data visualization showing the accuracy of SVM algorithms in predicting diabetes risk
# - **Audio:** *Narrator:* "These algorithms improve early detection and targeted treatment."
#
# **Scene 5 (35-40 seconds)**
# - **Visual:** Healthcare professionals using SVM-based tools in clinical settings
# - **Audio:** *Narrator:* "Empowering healthcare providers with data-driven insights."
#
# **Scene 6 (40-45 seconds)**
# - **Visual:** Global map highlighting the prevalence of diabetes
# - **Audio:** *Narrator:* "A global challenge, requiring collective efforts."
#
# **Scene 6 (45-50 seconds)**
# - **Visual:** Call to action message with contact details for diabetes support organizations
# - **Audio:** *Narrator:* "Join the fight against diabetes. Learn more and seek support today."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 4/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** A doctor examines a patient, surrounded by medical equipment.
# - **Audio:** "Early detection of diabetes is crucial."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** The doctor reviews the patient's data on a computer screen.
# - **Audio:** "Traditional methods often miss pre-diabetic conditions."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** A close-up of the patient's medical records.
# - **Audio:** "Over one-third of diabetes diagnoses are late due to missed pre-diabetic indicators."
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** A graph displays the rise in diabetes diagnoses.
# - **Audio:** "This poses a significant health risk."
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** A team of researchers gathers data for machine learning models.
# - **Audio:** "Machine learning offers hope for early detection."
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** The machine learning algorithm analyzes patient data.
# - **Audio:** "These models can identify pre-diabetic patients with high accuracy."
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Patients receive early interventions due to accurate pre-diabetic detection.
# - **Audio:** "Early detection enables timely interventions, improving patient outcomes."
#
# **Scene 7 (35-40 seconds)**
# - **Visual:** The logo of a healthcare provider or research institute appears on the screen.
# - **Audio:** "Let's work together to harness the power of technology for better diabetes care."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 5/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Diabetes Detection Storyboard**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Close-up of a person's face, showing concern.
# - **Audio:** " Diabetes is a serious condition that affects millions worldwide."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Data charts and graphs, representing diabetes statistics.
# - **Audio:** " Traditional methods of diagnosis have limitations."
#
# **Scene 2 (30-35 seconds)**
# - **Visual:** Scientists using computers and algorithms.
# - **Audio:** " Machine learning offers a promising solution for accurate diabetes detection."
#
# **Scene 3 (40-45 seconds)**
# - **Visual:** Comparison of different machine learning algorithms.
# - **Audio:** " SVM algorithm has shown superior performance in predicting diabetes."
#
# **Scene 4 (55-60 seconds)**
# - **Visual:** Close-up of a computer screen displaying a diabetes prediction model.
# - **Audio:** " Our research combines SVM and Naive Bayes methods for enhanced accuracy."
#
# **Scene 5 (70-75 seconds)**
# - **Visual:** Healthcare professionals using the diagnostic tool to assess patients.
# - **Audio:** " This tool provides real-time, data-driven predictions for better diabetes management."
#
# **Scene 6 (85-90 seconds)**
# - **Visual:** Patients smiling with relief after receiving an accurate diagnosis.
# - **Audio:** " Empowering healthcare professionals and patients in the fight against diabetes."
#
# **Scene 7 (105-110 seconds)**
# - **Visual:** Call-to-action graphic or website address.
# - **Audio:** " Visit our website to learn more and take control of your diabetes health. Together, we can make a difference."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 6/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Opening shot of a medical lab, data being analyzed on computer screens
# - **Audio:** Narrator: "Discover a breakthrough in disease detection, unlocking the power of AI."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Close-up of a doctor using a stethoscope on a patient
# - **Audio:** Narrator: "Introducing a joint AI algorithm, harnessing the strengths of two algorithms to enhance precision."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Transition to scientists working on the algorithm
# - **Audio:** Narrator: "Empowering healthcare professionals with data-driven insights."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Animated graphics illustrating the AI algorithm analyzing medical data
# - **Audio:** Narrator: "Statistical analysis reveals remarkable accuracy in classifying health data."
#
# **Scene 3 (25-30 seconds)**
# - **Visual:** Close-up of a smartphone with a health app
# - **Audio:** Narrator: "Early detection, faster diagnosis, improved outcomes."
#
# **Scene 4 (30-35 seconds)**
# - **Visual:** Patient receiving treatment based on AI-driven insights
# - **Audio:** Narrator: "Empowering patients with knowledge and peace of mind."
#
# **Scene 5 (40-45 seconds)**
# - **Visual:** Montage of healthcare professionals using the AI solution
# - **Audio:** Narrator: "Transforming healthcare, one diagnosis at a time."
#
# **Scene 5 (45-50 seconds)**
# - **Visual:** Close-up of the AI platform logo
# - **Audio:** Narrator: "Join the revolution in disease detection. Contact us today."
#
# **Scene 6 (55-60 seconds)**
# - **Visual:** Patient smiling, holding hands with a doctor
# - **Audio:** Narrator: "Together, we're unlocking the future of healthcare."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 7/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5s):**
# - **Visual:** Close-up shot of a beating heart surrounded by statistics on heart disease.
# - **Audio:** Voiceover: "Heart disease, a leading cause of death globally."
#
# **Scene 1 (5-10s):**
# - **Visual:** Microscope footage of cancer cells.
# - **Audio:** Voiceover: "Cancer, another major health concern, claims millions of lives each year."
#
# **Scene 2 (10-15s):**
# - **Visual:** Graph showing the rise in diabetes cases worldwide.
# - **Audio:** Voiceover: "Diabetes, a chronic condition affecting millions, can lead to severe complications."
#
# **Scene 3 (15-20s):**
# - **Visual:** Researchers working on machine learning algorithms.
# - **Audio:** Voiceover: "Advancements in machine learning offer hope for early detection and prevention."
#
# **Scene 4 (20-25s):**
# - **Visual:** Demonstration of how algorithms analyze data to identify potential health issues.
# - **Audio:** Voiceover: "By analyzing data patterns, algorithms can pinpoint individuals at risk."
#
# **Scene 5 (25-30s):**
# - **Visual:** Animated sequence showing algorithms predicting health outcomes.
# - **Audio:** Voiceover: "Early detection empowers individuals to take preventive measures."
#
# **Scene 6 (30-40s):**
# - **Visual:** Montage of people using wearable devices and apps.
# - **Audio:** Voiceover: "Technology empowers individuals to monitor their health and share data with healthcare providers."
#
# **Scene 7 (40-45s):**
# - **Visual:** Close-up of a smiling doctor.
# - **Audio:** Voiceover: "With early detection and intervention, we can reduce the burden of heart disease, cancer, and diabetes."
#
# **Call to Action (45-50s):**
# - **Visual:** On-screen message: "Get tested regularly. Take control of your health today."
# - **Audio:** Voiceover: "Together, we can create a healthier future for all."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 8/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Diabetes Prediction Storyboard (3 Minutes)**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Data points on a graph scatter plot
# - **Audio:** "Diabetes affects millions worldwide"
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Bar graph showing prevalence of diabetes
# - **Audio:** "Predicting diabetes is crucial for early intervention"
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Medical personnel collecting data from patients
# - **Audio:** "Researchers use machine learning to analyze data"
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** Flowchart of machine learning process
# - **Audio:** "Various algorithms have been tested"
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** Graph showing SVM algorithm accuracy
# - **Audio:** "SVM performs well, with 94% accuracy"
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** Another graph showing Naive Bayes accuracy
# - **Audio:** "Naive Bayes also effective, with similar results"
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Diabetes risk factors and symptoms on screen
# - **Audio:** "Prediction can help identify high-risk individuals"
#
# **Scene 7 (35-40 seconds)**
# - **Visual:** Doctors examining a patient
# - **Audio:** "Early detection enables timely treatment and management"
#
# **Call to Action (40-45 seconds)**
# - **Visual:** Logo or website of organization providing diabetes support
# - **Audio:** "Visit our website for more information and resources"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 9/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5s)**
# - **Visual:** Animated statistics showing the prevalence of diabetes
# - **Audio:** Narrator: "Diabetes affects millions worldwide, and early detection is crucial."
#
# **Scene 1 (5-10s)**
# - **Visual:** Close-up of a glucose meter
# - **Audio:** Narrator: "Traditional methods can be inaccurate or time-consuming."
#
# **Scene 2 (10-15s)**
# - **Visual:** Computer screen displaying data analysis
# - **Audio:** Narrator: "Machine learning algorithms offer a promising solution for early detection."
#
# **Scene 2 (15-20s)**
# - **Visual:** Chart comparing the performance of different algorithms
# - **Audio:** Narrator: "Researchers have explored various algorithms with varying efficiency."
#
# **Scene 3 (20-25s)**
# - **Visual:** Doctors and patients using a diabetes detection tool
# - **Audio:** Narrator: "Hybrid approaches, combining different algorithms, show potential."
#
# **Scene 4 (25-30s)**
# - **Visual:** Original dataset being analyzed
# - **Audio:** Narrator: "Our study uses a unique dataset from medical examinations in Kosovo."
#
# **Scene 5 (30-35s)**
# - **Visual:** Joint use of machine learning algorithms
# - **Audio:** Narrator: "By combining two algorithms, we enhance decision reliability."
#
# **Scene 6 (35-40s)**
# - **Visual:** Enlarged glowing green "yes/no" decision zone
# - **Audio:** Narrator: "This creates a more accurate and reliable diagnosis."
#
# **Scene 7 (40-45s)**
# - **Visual:** Call to action on screen
# - **Audio:** Narrator: "Join our research to improve diabetes detection and support healthier lives."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 10/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** A doctor talking to a patient about diabetes risk
# - **Audio:** "Understanding your diabetes risk can help you take preventive measures."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Close-up of a glucose meter and a blood sample
# - **Audio:** "Screening can identify those at risk for developing diabetes."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Montage of people engaging in activities that can lead to diabetes
# - **Audio:** "Factors like obesity, inactivity, and poor diet can increase your risk."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** A group of people in a support group
# - **Audio:** "Early detection and management are crucial for preventing complications."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** Interview with a medical expert
# - **Audio:** "Screening can detect prediabetes, a 'grey zone' that warrants further evaluation."
#
# **Scene 4 (25-30 seconds)**
# - **Visual:** Close-up of a dataset and analysis tools
# - **Audio:** "Our research analyzed data from 402 individuals to identify risk factors."
#
# **Scene 5 (30-35 seconds)**
# - **Visual:** Animation of a decision-making process
# - **Audio:** "The screening results can guide personalized interventions."
#
# **Scene 6 (35-40 seconds)**
# - **Visual:** People receiving lifestyle counseling and support
# - **Audio:** "Lifestyle changes and medical monitoring can effectively manage diabetes risk."
#
# **Scene 7 (40-45 seconds)**
# - **Visual:** A confident and healthy person
# - **Audio:** "Early detection and intervention empower you to take control of your health."
#
# **Call to Action (45-55 seconds)**
# - **Visual:** Contact information for screening and support programs
# - **Audio:** "Don't wait until it's too late. Get screened today. Your future health depends on it."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 11/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Opening shot of a diverse group of people smiling and engaging in various activities.
# - **Audio:** "Regular diet and physical activity are crucial for maintaining a healthy life."
#
# **Scene 2 (5-10 seconds)**
# - **Visual:** Show a person checking their BMI on a scale.
# - **Audio:** "Body Mass Index (BMI) is a measure of body fat based on height and weight."
#
# **Scene 3 (10-15 seconds)**
# - **Visual:** Depict a family gathered around a table enjoying a meal.
# - **Audio:** "Regular meals help maintain healthy blood sugar levels."
#
# **Scene 4 (15-20 seconds)**
# - **Visual:** Show a montage of people exercising in different settings.
# - **Audio:** "Physical activity is essential for reducing the risk of chronic diseases."
#
# **Scene 5 (20-25 seconds)**
# - **Visual:** Highlight the importance of family history in assessing health risks.
# - **Audio:** "Understanding your family's health history can provide valuable insights."
#
# **Scene 6 (25-30 seconds)**
# - **Visual:** Display a chart summarizing the research findings.
# - **Audio:** "Research suggests that maintaining a regular diet, engaging in physical activity, and considering family history can significantly improve health outcomes."
#
# **Scene 7 (30-35 seconds)**
# - **Visual:** Conclude with a call to action to adopt healthy habits.
# - **Audio:** "Take control of your health by making informed choices about your diet, exercise, and lifestyle."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 12/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Statistics of pre-meal and post-meal glucose levels of 80 patients diagnosed with type 2 diabetes
# - **Audio:** "Our research reveals alarming trends in diabetes diagnosis."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Comparison of blood pressure readings between diabetic and non-diabetic patients
# - **Audio:** "Elevated blood pressure is a concerning indicator."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Family history, diet, and physical activity data of diabetic patients
# - **Audio:** "Lifestyle factors significantly contribute to diabetes risk."
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** Animation of the SVM algorithm dividing data points into classes
# - **Audio:** "Machine learning algorithms can aid in accurate diabetes detection."
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** Graph showing the high accuracy of the SVM model in classifying diabetic and non-diabetic patients
# - **Audio:** "This innovative approach offers a promising tool for early diagnosis."
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** Close-up of a smartwatch tracking health data
# - **Audio:** "Empowering individuals with accessible health monitoring is crucial."
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Call-to-action message encouraging preventive measures and regular check-ups
# - **Audio:** "Take control of your health. Prevent or manage diabetes with timely intervention. Get screened today!"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 13/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Abstract representation of two classes of data points in a multi-dimensional space
# - **Audio:** Narrator: "In machine learning, we often encounter the task of classifying data into different categories."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Zoom in on the boundary between the two data classes, highlighting the maximum-margin hyperplane
# - **Audio:** Narrator: "To achieve optimal classification, we seek the hyperplane that provides the greatest separation between the classes."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Introduce the concept of support vectors, showing the data points closest to the maximum-margin hyperplane
# - **Audio:** Narrator: "The data points that define this optimal boundary are known as support vectors."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Illustrate how support vectors of two classes define two parallel hyperplanes
# - **Audio:** Narrator: "Support vectors from different classes help establish the boundaries and improve the classifier's accuracy."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** Show the mathematical representation of data points and the hyperplane equation
# - **Audio:** Narrator: "The data points can be represented mathematically, and the hyperplane is defined by the equation W*X + B = 0."
#
# **Scene 4 (25-30 seconds)**
# - **Visual:** Animate the process of dividing the data into two classes using the hyperplane
# - **Audio:** Narrator: "This hyperplane effectively separates the data into their respective classes, minimizing errors."
#
# **Scene 5 (30-35 seconds)**
# - **Visual:** Display the impact of a larger margin between the hyperplanes on the classifier's performance
# - **Audio:** Narrator: "A wider margin between the hyperplanes enhances the generalization ability of the classifier."
#
# **Scene 6 (35-40 seconds)**
# - **Visual:** Summarize key learning points and potential applications of this technique
# - **Audio:** Narrator: "In summary, the maximum-margin hyperplane method provides an effective approach for data classification, offering improved accuracy and generalization."
#
# **Call to Action:**
# **Visual:** Display a website or platform where viewers can access further resources on the topic
# **Audio:** Narrator: "Visit our website for more insights into machine learning techniques and their applications."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 14/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Opening shot of a diverse group of people smiling and interacting.
# - **Audio:** Narrator: "Technology empowers us to connect and innovate."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Close-up of a person using a smartphone to make a video call.
# - **Audio:** Narrator: "But what if technology could also help us improve our health and well-being?"
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Montage of people using fitness trackers and other health-related technologies.
# - **Audio:** Narrator: "The intersection of technology and healthcare is rapidly growing, offering new possibilities for personalized care."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Close-up of a person's face as they receive a health diagnosis from a doctor.
# - **Audio:** Person: "I'm so relieved to finally have an answer."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** Animated infographic showing the benefits of using technology in healthcare.
# - **Audio:** Narrator: "Technology can provide real-time monitoring, personalized treatment plans, and accessible health information."
#
# **Scene 3 (25-30 seconds)**
# - **Visual:** Shots of people using health apps and online resources.
# - **Audio:** Narrator: "Empowering individuals to take control of their health."
#
# **Scene 4 (30-35 seconds)**
# - **Visual:** Close-up of a person's hand holding a smartphone with a health app.
# - **Audio:** Person: "Technology is giving me peace of mind."
#
# **Scene 4 (35-40 seconds)**
# - **Visual:** Montage of people using technology to improve their health and well-being.
# - **Audio:** Narrator: "Technology is transforming healthcare, making it more accessible, personalized, and empowering."
#
# **Scene 5 (40-45 seconds)**
# - **Visual:** Group of people celebrating a health achievement.
# - **Audio:** Narrator: "Together, let's embrace technology to create a healthier future."
#
# **Scene 5 (45-50 seconds)**
# - **Visual:** Logo of a health organization or campaign.
# - **Audio:** Call to action: "Join us in the journey towards a healthier tomorrow."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 15/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated gears and cogs, symbolizing statistical modeling.
# - **Audio:** "Statistical modeling simplifies complex relationships using linear functions."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Scientists examining data under a microscope.
# - **Audio:** "However, real-life data often involves variables that are not equally important or independent."
#
# **Scene 2 (30-35 seconds)**
# - **Visual:** A diagram showing the calculation of probability based on multiple attributes.
# - **Audio:** "Despite these assumptions, statistical modeling can still yield surprisingly accurate results in practice."
#
# **Scene 3 (60-65 seconds)**
# - **Visual:** A researcher analyzing data on a computer screen.
# - **Audio:** "Statistical modeling empowers us to predict outcomes based on historical data."
#
# **Scene 4 (90-95 seconds)**
# - **Visual:** A doctor reviewing patient data.
# - **Audio:** "In healthcare, it helps identify potential risks and improve patient outcomes."
#
# **Scene 5 (120-125 seconds)**
# - **Visual:** A businesswoman making data-driven decisions.
# - **Audio:** "In business, it enables better decision-making and increased profitability."
#
# **Scene 6 (150-155 seconds)**
# - **Visual:** A montage of scientific discoveries and technological advancements.
# - **Audio:** "Statistical modeling drives innovation and progress in various fields."
#
# **Scene 7 (175-180 seconds)**
# - **Visual:** Call to action to empower viewers with statistical literacy.
# - **Audio:** "Embrace statistical modeling to unlock the power of data and make informed decisions."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 16/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** [Animation depicting a data scientist analyzing medical data]
# - **Audio:** [Narrator] "Unlocking the Secrets of Diabetes Detection with AI"
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** [Data visualization showing the Gaussian distribution]
# - **Audio:** "Predicting the probability of diabetes using mathematical models"
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** [Animation illustrating the Naive Bayes and SVM classifiers]
# - **Audio:** "Introducing two powerful classifiers: Naive Bayes and SVM"
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** [Data visualization showing the training and classification process]
# - **Audio:** "Training the classifiers to recognize patterns in medical data"
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** [Diagram illustrating the calculation of probability]
# - **Audio:** "Determining the likelihood of a patient having diabetes"
#
# **Scene 4 (25-30 seconds)**
# - **Visual:** [Animation of AI-powered diagnostic tool being used by a doctor]
# - **Audio:** "Empowering healthcare professionals with AI for accurate diagnoses"
#
# **Scene 5 (30-35 seconds)**
# - **Visual:** [Testimonial from a patient whose life was improved by the AI tool]
# - **Audio:** "AI making a tangible difference in the lives of patients"
#
# **Scene 6 (35-40 seconds)**
# - **Visual:** [Call to action graphic with website or contact information]
# - **Audio:** [Narrator] "Join the revolution in diabetes detection. Visit our website for more information!"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 17/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated data flowing into a computer screen
# - **Audio:** "Diabetes detection is a crucial medical challenge."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Two classifiers processing the data simultaneously
# - **Audio:** "We've developed a novel approach using multiple classifiers."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** SVM and Naïve Bayes algorithms analyzing the data
# - **Audio:** "SVM utilizes a polynomial kernel for complexity."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Data being divided into training and testing sets
# - **Audio:** "Data is split into training and testing sets for algorithm training."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** Classifier being developed from the training data
# - **Audio:** "A classifier is extracted from the training set."
#
# **Scene 3 (25-30 seconds)**
# - **Visual:** Testing data being evaluated by the derived classifier
# - **Audio:** "Testing instances are tested on the derived classifier."
#
# **Scene 4 (30-35 seconds)**
# - **Visual:** Classifications being assigned to each data point
# - **Audio:** "Each data point is classified as 0, 1, or 'grey zone'."
#
# **Scene 5 (35-40 seconds)**
# - **Visual:** Patients benefiting from improved diabetes detection
# - **Audio:** "Enhanced detection accuracy can improve patient outcomes."
#
# **Scene 6 (40-45 seconds)**
# - **Visual:** World map with diabetes data highlighted
# - **Audio:** "Our approach has global implications for diabetes care."
#
# **Call to Action (45-49 seconds)**
# - **Visual:** Logo and contact information
# - **Audio:** "Join our research team to contribute to diabetes detection advancements."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 18/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated title card with "Diabetes Detection App"
# - **Audio:** (Narrator) "Introducing a cutting-edge app revolutionizing diabetes screening."
#
# **Scene 2 (5-10 seconds)**
# - **Visual:** Smartphone is shown being used
# - **Audio:** (Narrator) "Using sophisticated algorithms..."
#
# **Scene 3 (10-15 seconds)**
# - **Visual:** Close-up of app's interface
# - **Audio:** (Narrator) "...the app analyzes user data to assess diabetes risk."
#
# **Scene 4 (15-20 seconds)**
# - **Visual:** Data visualization graphs
# - **Audio:** (Narrator) "Data is meticulously evaluated..."
#
# **Scene 5 (20-25 seconds)**
# - **Visual:** App displaying personalized risk assessment
# - **Audio:** (Narrator) "...providing tailored estimates."
#
# **Scene 6 (25-30 seconds)**
# - **Visual:** Users interacting with the app
# - **Audio:** (Narrator) "The app empowers users to take an active role in their health."
#
# **Call to Action (30 seconds)**
# - **Visual:** App logo and download instructions
# - **Audio:** (Narrator) "Download the Diabetes Detection App now and take control of your health."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 19/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated introduction to the diabetes detection application
# - **Audio:** "Introducing a revolutionary tool for diabetes diagnosis"
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Display of the GUI in Fig. 1
# - **Audio:** "Empowering healthcare professionals with an advanced interface"
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Illustration of data acquisition mode
# - **Audio:** "Collecting essential data to enhance accuracy"
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** Showcase of assessment mode
# - **Audio:** "Predicting pre-diabetic and diabetic conditions with confidence"
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** Demonstration of SVM and Naïve Bayes classification
# - **Audio:** "Combining algorithms for reliable results"
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** Display of high-reliability output
# - **Audio:** "Accurate predictions for informed decision-making"
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Monitoring for uncertain outputs
# - **Audio:** "Ensuring precise diagnoses for better patient outcomes"
#
# **Scene 7 (35-40 seconds)**
# - **Visual:** Call-to-action for healthcare professionals
# - **Audio:** "Join the fight against diabetes. Embrace this innovative technology for better patient care."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 20/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
#
# - **Visual:** Abstract representation of medical data (e.g., graphs, charts)
# - **Audio:** "Diabetes detection through advanced machine learning techniques."
#
# **Scene 1 (5-10 seconds)**
#
# - **Visual:** Data being split into training and evaluation sets
# - **Audio:** "Data undergoes a quasi-random split for analysis."
#
# **Scene 2 (10-15 seconds)**
#
# - **Visual:** Close-up of a cross-validation process
# - **Audio:** "Cross-validation ensures reliable results by repeatedly training and evaluating the model."
#
# **Scene 3 (15-20 seconds)**
#
# - **Visual:** Graph showing the accuracy of the model
# - **Audio:** "The SVM classifier demonstrates high accuracy in diabetes detection."
#
# **Scene 4 (20-25 seconds)**
#
# - **Visual:** Montage of people with diabetes benefiting from early detection
# - **Audio:** "Early and accurate detection can significantly improve outcomes."
#
# **Scene 5 (25-30 seconds)**
#
# - **Visual:** Scientists collaborating and advancing research
# - **Audio:** "Continuous research is vital for improving diabetes detection methods."
#
# **Scene 6 (30-35 seconds)**
#
# - **Visual:** Call-to-action message (e.g., "Join the fight against diabetes. Get tested.")
# - **Audio:** "Take action today to protect your health."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 21/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Abstract data visualization of a dataset.
# - **Audio:** "Artificial Intelligence algorithms, like SVM and Naïve Bayes, have been used to classify complex datasets."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Animated graphs illustrating the accuracy of the algorithms.
# - **Audio:** "Specifically, SVM achieved an accuracy of approximately 95.52%, while Naïve Bayes achieved approximately 94.53%."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Close-up of a computer screen displaying code.
# - **Audio:** "These algorithms have demonstrated high stability, with a variation of only +/- 1% in classification performance."
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** Table on the screen showing the detailed classification results.
# - **Audio:** "For the SVM algorithm, 192 records were correctly classified and 9 were incorrectly classified."
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** Side-by-side comparison of the two algorithms.
# - **Audio:** "For the Naïve Bayes algorithm, 190 records were correctly classified and 11 were incorrectly classified."
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** Researchers analyzing and discussing the results.
# - **Audio:** "These findings indicate that both algorithms can effectively classify complex datasets, with SVM having a slightly higher accuracy."
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Call-to-action message on the screen.
# - **Audio:** "For more information on these algorithms and their applications, please visit our website."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 22/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5s)**
# - **Visual:** Intro slide with title and research topic
# - **Audio:** "Exploring classification methods for complex data"
#
# **Scene 1 (5-10s)**
# - **Visual:** Comparison of SVM and Naive Bayes algorithms
# - **Audio:** "SVM outperforms Naive Bayes in accuracy, but the difference is minimal"
#
# **Scene 2 (10-15s)**
# - **Visual:** Visual representation of precision and recall metrics
# - **Audio:** "Precision measures true positives while recall focuses on minimizing false negatives"
#
# **Scene 3 (15-20s)**
# - **Visual:** Example of false positives and false negatives
# - **Audio:** "False positives misclassify data, while false negatives miss potential findings"
#
# **Scene 4 (20-25s)**
# - **Visual:** Animated visualization of precision and recall calculations
# - **Audio:** "Precision divides true positives by all positives, and recall divides true positives by all actual positives"
#
# **Scene 5 (25-30s)**
# - **Visual:** Demonstration of how performance metrics guide model selection
# - **Audio:** "Precision and recall help identify the best algorithm for the specific classification task"
#
# **Scene 6 (30-35s)**
# - **Visual:** Call to action with research website or contact information
# - **Audio:** "Visit our website for more insights into complex data classification methods"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 23/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** **Title card:** "Enhancing Medical Diagnosis Reliability"
# - **Audio:** **Narrator:** "Artificial intelligence is transforming the field of medical diagnosis."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** **Stats from Table III:** SVM and Naïve Bayes precision and recall values
# - **Audio:** **Narrator:** "Machine learning algorithms can assist doctors in making more precise diagnoses."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** **Flowchart:** Illustrating the joint implementation process
# - **Audio:** **Narrator:** "By combining two algorithms, we can improve diagnosis accuracy."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** **Percentage bar:** Showing 94.77% validity rate
# - **Audio:** **Narrator:** "Our implementation achieves a high rate of reliable diagnoses."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** **Animation:** Doctors using AI to assist in diagnosis
# - **Audio:** **Narrator:** "This enhanced reliability empowers doctors to make more confident decisions."
#
# **Scene 4 (25-30 seconds)**
# - **Visual:** **Patient testimonial:** "I trust my diagnosis more knowing AI is involved."
# - **Audio:** **Narrator:** "Patients benefit from increased peace of mind."
#
# **Scene 5 (30-35 seconds)**
# - **Visual:** **Call to action:** "Integrate AI into medical diagnostics to improve patient outcomes."
# - **Audio:** **Narrator:** "Let's harness the power of AI to make healthcare more reliable and effective."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 24/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Close-up of a patient undergoing a diabetes screening.
# - **Audio:** "Diabetes is a major health concern, affecting millions worldwide."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Montage of medical professionals using medical equipment to diagnose diabetes.
# - **Audio:** "Early detection is crucial for effective management."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Two independent classifiers classifying diabetes cases.
# - **Audio:** "Traditionally, diabetes detection involves multiple assessments."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Close-up of the datasets used for classification.
# - **Audio:** "Datasets can vary, leading to potential differences in results."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** A computer screen displays the joint implementation of two algorithms.
# - **Audio:** "Our research explored a new approach."
#
# **Scene 3 (25-30 seconds)**
# - **Visual:** The joint algorithm classifying diabetes cases with higher accuracy.
# - **Audio:** "The combined approach demonstrated significant improvement in accuracy."
#
# **Scene 4 (30-35 seconds)**
# - **Visual:** A doctor using the computer-based support tool.
# - **Audio:** "This tool aims to assist healthcare professionals."
#
# **Scene 5 (35-40 seconds)**
# - **Visual:** Patients receiving diabetes screening and support.
# - **Audio:** "Early diagnosis and timely intervention can improve outcomes."
#
# **Scene 6 (40-45 seconds)**
# - **Visual:** A call to action for viewers to support diabetes research.
# - **Audio:** "Join the fight against diabetes. Empower healthcare professionals with this breakthrough tool."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 25/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated data points flowing into a model
# - **Audio:** "Introducing a novel approach to diabetes detection"
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Comparison of new dataset to previous ones
# - **Audio:** "Leveraging a unique dataset with enhanced attributes"
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Execution of SVM and Naïve Bayes algorithms
# - **Audio:** "Independent execution of two algorithms"
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** Combination of algorithm outputs
# - **Audio:** "Joint decision-making for reliability"
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** Statistical results displayed on a graph
# - **Audio:** "Impressive performance of SVM (95.52%) and Naïve Bayes (94.52%)"
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** Illustration of joint implementation and possible outcomes
# - **Audio:** "Joint implementation: diagnosis, no diagnosis, or further examination"
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Animated diabetes detection system
# - **Audio:** "Enhancing diabetes detection with this innovative approach"
#
# **Scene 7 (35-40 seconds)**
# - **Visual:** Call to action message
# - **Audio:** "Empowering healthcare professionals for more accurate diabetes detection"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 26/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Scene 1 (0-5 seconds)**
# - **Visual:** A close-up shot of a person using a computer with an algorithm-driven platform.
# - **Audio:** Narrator introduces the topic: "Explore the power of machine learning algorithms in improving disease detection."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** A graph showing how algorithms provide different results.
# - **Audio:** "Our research reveals that different algorithm approaches can vary in their effectiveness."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** A diagram illustrating the accuracy improvement of answers.
# - **Audio:** "When specific conditions are met, the accuracy of answers can be significantly enhanced, reaching up to 97.6%."
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** A simulation showing the minimization of false negatives.
# - **Audio:** "This approach minimizes false negative answers, a crucial aspect in medical diagnostics."
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** A blueprint of a diabetes classification tool.
# - **Audio:** "Our methodology provides a blueprint for constructing similar applications in disease detection."
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** A group of people using a user-friendly health app.
# - **Audio:** "Imagine a user-friendly app that enables personal self-screening for diabetes or prediabetes."
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** A montage of people benefiting from early detection.
# - **Audio:** "Early detection is crucial. This tool empowers individuals to take proactive steps toward their health."
#
# **Call to Action (35-40 seconds)**
# - **Visual:** The app logo fades in.
# - **Audio:** Narrator: "Join the movement towards personalized healthcare by trying our app today. Together, let's revolutionize disease detection."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 27/27...
#
# ✅ 3-Minute Storyboard with Timestamps generated successfully.
#
# 🎬 **Generated 3-Minute Storyboard with 5-Second Timestamps:**
#
# **Video Storyboard Script**
#
# **Scene 1 (0-5 seconds)**
#
# - **Visual:** Close-up on a medical tool
# - **Audio:** (Narrator) Innovations in healthcare technology promise better treatment outcomes.
#
# **Scene 1 (5-10 seconds)**
#
# - **Visual:** Doctor using the tool to examine a patient
# - **Audio:** (Narrator) But evaluating the effectiveness of these tools is crucial.
#
# **Scene 2 (10-15 seconds)**
#
# - **Visual:** Data analysis screen showing the tool's performance
# - **Audio:** (Narrator) We need robust methods to assess accuracy and efficiency.
#
# **Scene 3 (15-20 seconds)**
#
# - **Visual:** Patients from different cultural backgrounds
# - **Audio:** (Narrator) Cultural factors can impact treatment effectiveness.
#
# **Scene 4 (20-25 seconds)**
#
# - **Visual:** Collaboration between researchers and practitioners
# - **Audio:** (Narrator) Further research is needed to address these challenges.
#
# **Scene 5 (25-30 seconds)**
#
# - **Visual:** Advanced medical imaging and analytics
# - **Audio:** (Narrator) By combining innovative methods, we can optimize treatment for all.
#
# **Scene 6 (30-35 seconds)**
#
# - **Visual:** Doctor and patient discussing improved outcomes
# - **Audio:** (Narrator) Together, we can harness technology to empower healthcare professionals and improve patient lives.
#
# **Scene 7 (35-40 seconds)**
#
# - **Visual:** Call-to-action graphic
# ...
#
# **Scene 5 (30-35 seconds)**
# - **Visual:** [Testimonial from a patient whose life was improved by the AI tool]
# - **Audio:** "AI making a tangible difference in the lives of patients"
#
# **Scene 6 (35-40 seconds)**
# - **Visual:** [Call to action graphic with website or contact information]
# - **Audio:** [Narrator] "Join the revolution in diabetes detection. Visit our website for more information!"
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated data flowing into a computer screen
# - **Audio:** "Diabetes detection is a crucial medical challenge."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Two classifiers processing the data simultaneously
# - **Audio:** "We've developed a novel approach using multiple classifiers."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** SVM and Naïve Bayes algorithms analyzing the data
# - **Audio:** "SVM utilizes a polynomial kernel for complexity."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Data being divided into training and testing sets
# - **Audio:** "Data is split into training and testing sets for algorithm training."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** Classifier being developed from the training data
# - **Audio:** "A classifier is extracted from the training set."
#
# **Scene 3 (25-30 seconds)**
# - **Visual:** Testing data being evaluated by the derived classifier
# - **Audio:** "Testing instances are tested on the derived classifier."
#
# **Scene 4 (30-35 seconds)**
# - **Visual:** Classifications being assigned to each data point
# - **Audio:** "Each data point is classified as 0, 1, or 'grey zone'."
#
# **Scene 5 (35-40 seconds)**
# - **Visual:** Patients benefiting from improved diabetes detection
# - **Audio:** "Enhanced detection accuracy can improve patient outcomes."
#
# **Scene 6 (40-45 seconds)**
# - **Visual:** World map with diabetes data highlighted
# - **Audio:** "Our approach has global implications for diabetes care."
#
# **Call to Action (45-49 seconds)**
# - **Visual:** Logo and contact information
# - **Audio:** "Join our research team to contribute to diabetes detection advancements."
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated title card with "Diabetes Detection App"
# - **Audio:** (Narrator) "Introducing a cutting-edge app revolutionizing diabetes screening."
#
# **Scene 2 (5-10 seconds)**
# - **Visual:** Smartphone is shown being used
# - **Audio:** (Narrator) "Using sophisticated algorithms..."
#
# **Scene 3 (10-15 seconds)**
# - **Visual:** Close-up of app's interface
# - **Audio:** (Narrator) "...the app analyzes user data to assess diabetes risk."
#
# **Scene 4 (15-20 seconds)**
# - **Visual:** Data visualization graphs
# - **Audio:** (Narrator) "Data is meticulously evaluated..."
#
# **Scene 5 (20-25 seconds)**
# - **Visual:** App displaying personalized risk assessment
# - **Audio:** (Narrator) "...providing tailored estimates."
#
# **Scene 6 (25-30 seconds)**
# - **Visual:** Users interacting with the app
# - **Audio:** (Narrator) "The app empowers users to take an active role in their health."
#
# **Call to Action (30 seconds)**
# - **Visual:** App logo and download instructions
# - **Audio:** (Narrator) "Download the Diabetes Detection App now and take control of your health."
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated introduction to the diabetes detection application
# - **Audio:** "Introducing a revolutionary tool for diabetes diagnosis"
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Display of the GUI in Fig. 1
# - **Audio:** "Empowering healthcare professionals with an advanced interface"
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Illustration of data acquisition mode
# - **Audio:** "Collecting essential data to enhance accuracy"
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** Showcase of assessment mode
# - **Audio:** "Predicting pre-diabetic and diabetic conditions with confidence"
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** Demonstration of SVM and Naïve Bayes classification
# - **Audio:** "Combining algorithms for reliable results"
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** Display of high-reliability output
# - **Audio:** "Accurate predictions for informed decision-making"
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Monitoring for uncertain outputs
# - **Audio:** "Ensuring precise diagnoses for better patient outcomes"
#
# **Scene 7 (35-40 seconds)**
# - **Visual:** Call-to-action for healthcare professionals
# - **Audio:** "Join the fight against diabetes. Embrace this innovative technology for better patient care."
# **Scene 1 (0-5 seconds)**
#
# - **Visual:** Abstract representation of medical data (e.g., graphs, charts)
# - **Audio:** "Diabetes detection through advanced machine learning techniques."
#
# **Scene 1 (5-10 seconds)**
#
# - **Visual:** Data being split into training and evaluation sets
# - **Audio:** "Data undergoes a quasi-random split for analysis."
#
# **Scene 2 (10-15 seconds)**
#
# - **Visual:** Close-up of a cross-validation process
# - **Audio:** "Cross-validation ensures reliable results by repeatedly training and evaluating the model."
#
# **Scene 3 (15-20 seconds)**
#
# - **Visual:** Graph showing the accuracy of the model
# - **Audio:** "The SVM classifier demonstrates high accuracy in diabetes detection."
#
# **Scene 4 (20-25 seconds)**
#
# - **Visual:** Montage of people with diabetes benefiting from early detection
# - **Audio:** "Early and accurate detection can significantly improve outcomes."
#
# **Scene 5 (25-30 seconds)**
#
# - **Visual:** Scientists collaborating and advancing research
# - **Audio:** "Continuous research is vital for improving diabetes detection methods."
#
# **Scene 6 (30-35 seconds)**
#
# - **Visual:** Call-to-action message (e.g., "Join the fight against diabetes. Get tested.")
# - **Audio:** "Take action today to protect your health."
# **Scene 1 (0-5 seconds)**
# - **Visual:** Abstract data visualization of a dataset.
# - **Audio:** "Artificial Intelligence algorithms, like SVM and Naïve Bayes, have been used to classify complex datasets."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Animated graphs illustrating the accuracy of the algorithms.
# - **Audio:** "Specifically, SVM achieved an accuracy of approximately 95.52%, while Naïve Bayes achieved approximately 94.53%."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Close-up of a computer screen displaying code.
# - **Audio:** "These algorithms have demonstrated high stability, with a variation of only +/- 1% in classification performance."
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** Table on the screen showing the detailed classification results.
# - **Audio:** "For the SVM algorithm, 192 records were correctly classified and 9 were incorrectly classified."
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** Side-by-side comparison of the two algorithms.
# - **Audio:** "For the Naïve Bayes algorithm, 190 records were correctly classified and 11 were incorrectly classified."
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** Researchers analyzing and discussing the results.
# - **Audio:** "These findings indicate that both algorithms can effectively classify complex datasets, with SVM having a slightly higher accuracy."
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Call-to-action message on the screen.
# - **Audio:** "For more information on these algorithms and their applications, please visit our website."
# **Scene 1 (0-5s)**
# - **Visual:** Intro slide with title and research topic
# - **Audio:** "Exploring classification methods for complex data"
#
# **Scene 1 (5-10s)**
# - **Visual:** Comparison of SVM and Naive Bayes algorithms
# - **Audio:** "SVM outperforms Naive Bayes in accuracy, but the difference is minimal"
#
# **Scene 2 (10-15s)**
# - **Visual:** Visual representation of precision and recall metrics
# - **Audio:** "Precision measures true positives while recall focuses on minimizing false negatives"
#
# **Scene 3 (15-20s)**
# - **Visual:** Example of false positives and false negatives
# - **Audio:** "False positives misclassify data, while false negatives miss potential findings"
#
# **Scene 4 (20-25s)**
# - **Visual:** Animated visualization of precision and recall calculations
# - **Audio:** "Precision divides true positives by all positives, and recall divides true positives by all actual positives"
#
# **Scene 5 (25-30s)**
# - **Visual:** Demonstration of how performance metrics guide model selection
# - **Audio:** "Precision and recall help identify the best algorithm for the specific classification task"
#
# **Scene 6 (30-35s)**
# - **Visual:** Call to action with research website or contact information
# - **Audio:** "Visit our website for more insights into complex data classification methods"
# **Scene 1 (0-5 seconds)**
# - **Visual:** **Title card:** "Enhancing Medical Diagnosis Reliability"
# - **Audio:** **Narrator:** "Artificial intelligence is transforming the field of medical diagnosis."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** **Stats from Table III:** SVM and Naïve Bayes precision and recall values
# - **Audio:** **Narrator:** "Machine learning algorithms can assist doctors in making more precise diagnoses."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** **Flowchart:** Illustrating the joint implementation process
# - **Audio:** **Narrator:** "By combining two algorithms, we can improve diagnosis accuracy."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** **Percentage bar:** Showing 94.77% validity rate
# - **Audio:** **Narrator:** "Our implementation achieves a high rate of reliable diagnoses."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** **Animation:** Doctors using AI to assist in diagnosis
# - **Audio:** **Narrator:** "This enhanced reliability empowers doctors to make more confident decisions."
#
# **Scene 4 (25-30 seconds)**
# - **Visual:** **Patient testimonial:** "I trust my diagnosis more knowing AI is involved."
# - **Audio:** **Narrator:** "Patients benefit from increased peace of mind."
#
# **Scene 5 (30-35 seconds)**
# - **Visual:** **Call to action:** "Integrate AI into medical diagnostics to improve patient outcomes."
# - **Audio:** **Narrator:** "Let's harness the power of AI to make healthcare more reliable and effective."
# **Scene 1 (0-5 seconds)**
# - **Visual:** Close-up of a patient undergoing a diabetes screening.
# - **Audio:** "Diabetes is a major health concern, affecting millions worldwide."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Montage of medical professionals using medical equipment to diagnose diabetes.
# - **Audio:** "Early detection is crucial for effective management."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Two independent classifiers classifying diabetes cases.
# - **Audio:** "Traditionally, diabetes detection involves multiple assessments."
#
# **Scene 2 (15-20 seconds)**
# - **Visual:** Close-up of the datasets used for classification.
# - **Audio:** "Datasets can vary, leading to potential differences in results."
#
# **Scene 3 (20-25 seconds)**
# - **Visual:** A computer screen displays the joint implementation of two algorithms.
# - **Audio:** "Our research explored a new approach."
#
# **Scene 3 (25-30 seconds)**
# - **Visual:** The joint algorithm classifying diabetes cases with higher accuracy.
# - **Audio:** "The combined approach demonstrated significant improvement in accuracy."
#
# **Scene 4 (30-35 seconds)**
# - **Visual:** A doctor using the computer-based support tool.
# - **Audio:** "This tool aims to assist healthcare professionals."
#
# **Scene 5 (35-40 seconds)**
# - **Visual:** Patients receiving diabetes screening and support.
# - **Audio:** "Early diagnosis and timely intervention can improve outcomes."
#
# **Scene 6 (40-45 seconds)**
# - **Visual:** A call to action for viewers to support diabetes research.
# - **Audio:** "Join the fight against diabetes. Empower healthcare professionals with this breakthrough tool."
# **Scene 1 (0-5 seconds)**
# - **Visual:** Animated data points flowing into a model
# - **Audio:** "Introducing a novel approach to diabetes detection"
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** Comparison of new dataset to previous ones
# - **Audio:** "Leveraging a unique dataset with enhanced attributes"
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** Execution of SVM and Naïve Bayes algorithms
# - **Audio:** "Independent execution of two algorithms"
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** Combination of algorithm outputs
# - **Audio:** "Joint decision-making for reliability"
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** Statistical results displayed on a graph
# - **Audio:** "Impressive performance of SVM (95.52%) and Naïve Bayes (94.52%)"
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** Illustration of joint implementation and possible outcomes
# - **Audio:** "Joint implementation: diagnosis, no diagnosis, or further examination"
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** Animated diabetes detection system
# - **Audio:** "Enhancing diabetes detection with this innovative approach"
#
# **Scene 7 (35-40 seconds)**
# - **Visual:** Call to action message
# - **Audio:** "Empowering healthcare professionals for more accurate diabetes detection"
# **Scene 1 (0-5 seconds)**
# - **Visual:** A close-up shot of a person using a computer with an algorithm-driven platform.
# - **Audio:** Narrator introduces the topic: "Explore the power of machine learning algorithms in improving disease detection."
#
# **Scene 1 (5-10 seconds)**
# - **Visual:** A graph showing how algorithms provide different results.
# - **Audio:** "Our research reveals that different algorithm approaches can vary in their effectiveness."
#
# **Scene 2 (10-15 seconds)**
# - **Visual:** A diagram illustrating the accuracy improvement of answers.
# - **Audio:** "When specific conditions are met, the accuracy of answers can be significantly enhanced, reaching up to 97.6%."
#
# **Scene 3 (15-20 seconds)**
# - **Visual:** A simulation showing the minimization of false negatives.
# - **Audio:** "This approach minimizes false negative answers, a crucial aspect in medical diagnostics."
#
# **Scene 4 (20-25 seconds)**
# - **Visual:** A blueprint of a diabetes classification tool.
# - **Audio:** "Our methodology provides a blueprint for constructing similar applications in disease detection."
#
# **Scene 5 (25-30 seconds)**
# - **Visual:** A group of people using a user-friendly health app.
# - **Audio:** "Imagine a user-friendly app that enables personal self-screening for diabetes or prediabetes."
#
# **Scene 6 (30-35 seconds)**
# - **Visual:** A montage of people benefiting from early detection.
# - **Audio:** "Early detection is crucial. This tool empowers individuals to take proactive steps toward their health."
#
# **Call to Action (35-40 seconds)**
# - **Visual:** The app logo fades in.
# - **Audio:** Narrator: "Join the movement towards personalized healthcare by trying our app today. Together, let's revolutionize disease detection."
# **Video Storyboard Script**
#
# **Scene 1 (0-5 seconds)**
#
# - **Visual:** Close-up on a medical tool
# - **Audio:** (Narrator) Innovations in healthcare technology promise better treatment outcomes.
#
# **Scene 1 (5-10 seconds)**
#
# - **Visual:** Doctor using the tool to examine a patient
# - **Audio:** (Narrator) But evaluating the effectiveness of these tools is crucial.
#
# **Scene 2 (10-15 seconds)**
#
# - **Visual:** Data analysis screen showing the tool's performance
# - **Audio:** (Narrator) We need robust methods to assess accuracy and efficiency.
#
# **Scene 3 (15-20 seconds)**
#
# - **Visual:** Patients from different cultural backgrounds
# - **Audio:** (Narrator) Cultural factors can impact treatment effectiveness.
#
# **Scene 4 (20-25 seconds)**
#
# - **Visual:** Collaboration between researchers and practitioners
# - **Audio:** (Narrator) Further research is needed to address these challenges.
#
# **Scene 5 (25-30 seconds)**
#
# - **Visual:** Advanced medical imaging and analytics
# - **Audio:** (Narrator) By combining innovative methods, we can optimize treatment for all.
#
# **Scene 6 (30-35 seconds)**
#
# - **Visual:** Doctor and patient discussing improved outcomes
# - **Audio:** (Narrator) Together, we can harness technology to empower healthcare professionals and improve patient lives.
#
# **Scene 7 (35-40 seconds)**
#
# - **Visual:** Call-to-action graphic
# - **Audio:** (Narrator) Let's invest in research that drives better healthcare solutions for all.
