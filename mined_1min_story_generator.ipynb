# %%
import os
import textwrap
import re
import google.generativeai as genai

# ✅ Set Gemini API Key Securely
os.environ["GEMINI_API_KEY"] = "AIzaSyC6aH6dYQDuAhBKggZPRM7YtQisp9elvpc"  # Replace with your actual API key
GEN_API_KEY = os.getenv("GEMINI_API_KEY")
if not GEN_API_KEY:
    raise ValueError("❌ Error: Missing Gemini API Key! Set it using os.environ['GEMINI_API_KEY'] = 'YOUR_KEY'")

genai.configure(api_key=GEN_API_KEY)

# Function to split text into chunks
def split_text(text, max_chunk_size=800):
    return textwrap.wrap(text, width=max_chunk_size, break_long_words=False, replace_whitespace=False)

# 📌 Function to generate a concise **1-minute reel storyboard (~60s)**
def generate_1min_storyboard(text):
    try:
        model = genai.GenerativeModel("gemini-pro")
        prompt = f"""
        You are an expert in **video storytelling**. Your task is to generate a **structured, cinematic storyboard** for a **1-minute Instagram Reel (~60s total, 4 scenes of ~15s each)**.

        ### **Storyboard Requirements:**
        - **Concise & engaging** (like the Diabetes Detection example).
        - **4 scenes, each with clear visual and narration cues** (~15s per scene).
        - **Fast-paced, highly visual, and easy to understand.**
        - **Smooth transitions** between scenes.
        - **Powerful closing scene with a call to action.**

        ### **Storyboard Format Example:**
        ```
        **Scene 1 (0-15 seconds)**
        - **Visual:** [Describe the opening shot]
        - **Audio:** [Brief narration to introduce the topic]

        **Scene 2 (15-30 seconds)**
        - **Visual:** [Describe how the problem is shown]
        - **Audio:** [Explain why the problem matters]
        ...
        ```

        Now, generate a **1-minute Instagram Reel storyboard** based on the following research:
        **Research Text:** {text}
        """

        response = model.generate_content(prompt)
        if response and response.text:
            print("✅ 1-Minute Storyboard generated successfully.")
            return response.text
        else:
            print("❌ Error: Empty response from Gemini API.")
            return None

    except Exception as e:
        print(f"❌ Error generating storyboard: {e}")
        return None

# Extract references to tables, figures, and equations
def extract_references(text):
    ref_pattern = r"(Table|Figure|Equation|Fig|Eq)\s?\d+"
    references = re.findall(ref_pattern, text)
    return list(set(references))  # Remove duplicates

# Function to process research paper text and generate a 1-minute storyboard
def process_research_for_1min_storyboard(text):
    chunks = split_text(text, max_chunk_size=800)
    full_storyboard = ""
    all_references = set()

    for i, chunk in enumerate(chunks):
        print(f"\n🔹 Processing Chunk {i+1}/{len(chunks)}...\n")
        references = extract_references(chunk)

        storyboard = generate_1min_storyboard(chunk)  # Generate 1-minute storyboard

        if storyboard:
            print("\n🎬 **1-Minute Reel Storyboard:**\n")
            print(storyboard)
            full_storyboard += "\n" + storyboard

        print("\n🔷 References Detected:", references)
        all_references.update(references)

    return full_storyboard, all_references

# Example: Research paper text (Replace with actual text)
research_paper = """

"""

# Run the processing function
storyboard_1min, detected_references = process_research_for_1min_storyboard(research_paper)

# Print results
print("\n🔷 **Final 1-Minute Reel Storyboard:**\n")
print(storyboard_1min)

if detected_references:
    print("\n📌 References Detected:\n")
    print(", ".join(detected_references))
# Out:
# 🔹 Processing Chunk 1/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Animated infographic showing increasing numbers of people affected by diabetes
# - **Audio:** "Diabetes is on the rise, with over 346 million people worldwide"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-up of a person looking worried as they read a diabetes test result
# - **Audio:** "One-third of these cases go undetected in the early stages"
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A montage of people interacting with a diabetes prediction system
# - **Audio:** "Our intelligent system helps detect diabetes early, empowering you to make informed choices"
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Close-up of the system's logo and website address
# - **Audio:** "Visit our website [website address] to learn more and get your free screening today"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 2/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** A group of doctors study patient data on a computer.
# - **Audio:** "Unlocking the power of data to detect diabetes."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** A diagram shows how the algorithm analyzes data to identify patterns.
# - **Audio:** "Our algorithm uses advanced machine learning methods to sift through vast amounts of patient data."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A patient undergoes a medical examination.
# - **Audio:** "This groundbreaking technology empowers healthcare professionals to identify diabetes risk early, enabling prompt intervention."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A doctor discusses the value of the algorithm with a patient.
# - **Audio:** "Join the revolution in diabetes detection. Visit our website or consult your healthcare provider today."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 3/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of blood glucose meter displaying high reading.
# - **Audio:** "Diabetes: A silent epidemic affecting millions worldwide."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Montage of individuals experiencing diabetic complications (e.g., vision impairment, foot ulcers).
# - **Audio:** "From heart disease to blindness, diabetes takes a devastating toll on our health."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Animated infographic demonstrating how support vector machines (SVMs) can identify diabetes patterns in medical data.
# - **Audio:** "SVMs: A powerful tool for detecting diabetes early."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call to action: "Get screened today. Early detection is crucial for preventing complications."
# - **Audio:** "Join the fight against diabetes and empower your health with an SVM screening."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 4/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a person's face looking worried.
# - **Audio:** "Do you have these symptoms?"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Shots of people experiencing common diabetes symptoms: thirst, fatigue, weight loss.
# - **Audio:** Narration: "If yes, you may be at risk of prediabetes or diabetes."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Shots of healthcare professionals using computers and medical equipment.
# - **Audio:** Narration: "Machine learning algorithms can help early detection based on your data."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Patient smiling with a relieved expression.
# - **Audio:** Narration: "Get screened now. Don't wait to develop full-blown diabetes. #DiabetesDetection" (Call to action)
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 5/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Microscope images of pancreas cells
# - **Audio:** "Unlocking the potential of AI in diabetes detection."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Algorithms analyzing medical data
# - **Audio:** "AI algorithms can learn patterns in vast datasets, helping us identify diabetes risk."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** SVM and Naïve Bayes methods being used
# - **Audio:** "Specific machine learning methods, like SVM, excel in diabetes detection accuracy."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Real-time diabetes detection system
# - **Audio:** "With AI-powered tools, we can diagnose diabetes early and empower individuals to take preventive measures."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 6/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Graphic of two algorithms merging together, representing joint implementation.
# - **Audio:** "Introducing a breakthrough in data analysis..."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Charts and graphs showing high accuracy in data classification.
# - **Audio:** "Our research reveals the power of combining algorithms, minimizing weaknesses for better results."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Scientist working on a computer, representing experimental setup.
# - **Audio:** "This innovative approach enhances reliability, utilizing the strengths of each algorithm."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Logo and branding, accompanied by text "Learn more at [website address]".
# - **Audio:** "Unlock the potential of joint implementation for precise data analysis. Visit our website today!"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 7/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** A montage of medical images (X-rays, MRIs, etc.) showing people affected by heart disease, cancer, and diabetes.
# - **Audio:** Narrator: "Chronic diseases like heart disease, cancer, and diabetes affect millions worldwide."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Shots of doctors and patients using AI-powered diagnostic tools.
# - **Audio:** Narrator: "AI is revolutionizing healthcare by providing faster and more accurate detection of these diseases."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A timeline showing the decreasing cost of AI-powered diagnostic tools.
# - **Audio:** Narrator: "As AI becomes more accessible, early detection will become even more widespread."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A diverse group of people smiling and living healthier lives.
# - **Audio:** Narrator: "With AI, we can empower everyone to take control of their health and live longer, healthier lives. Join us in the fight against chronic diseases."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 8/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Storyboard for a 1-Minute Instagram Reel on Diabetes Detection**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a person's face, looking concerned.
# - **Audio:** Narrator: "Do you know the warning signs of diabetes?"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Montage of images showing symptoms of diabetes, such as excessive thirst, frequent urination, and unexplained weight loss.
# - **Audio:** Narrator: "Diabetes is a serious disease, affecting millions worldwide."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Person getting a blood test.
# - **Audio:** Narrator: "Early detection is crucial. Get tested to know your risk."
# - **Visual transitions:** zoom in on the blood drop on the test strip, indicating a positive result.
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** People living healthy lifestyles, such as exercising and eating healthy food.
# - **Audio:** Narrator: "Take charge of your health. Manage diabetes with lifestyle changes and medication."
# - **Call to action:** "Get tested today. Take control of your diabetes journey."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 9/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Storyboard for 1-Minute Instagram Reel**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Quick montage of researchers working in a lab, coding on computers, and analyzing data.
# - **Audio:** "Unlocking the power of data for diabetes detection..."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-up of a person taking a blood test. Focus on the data being collected and analyzed.
# - **Audio:** "Traditional methods can be limited, but new algorithms are changing the game."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Animated diagram showing how hybrid algorithms combine distance-based and statistical methods to improve accuracy.
# - **Audio:** "By combining different approaches, we can create more precise and reliable results."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Data being analyzed and interpreted. Focus on the practical applications of these algorithms in healthcare settings.
# - **Audio:** "Empowering medical professionals with cutting-edge tools to improve diabetes detection. Let's join forces against diabetes!"
# **Call to action:** "Find out more at [website address]."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 10/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a person's face, with a question mark on their forehead.
# - **Audio:** "Are you in the 'grey zone' when it comes to health?"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Panning shot of medical data (e.g., blood sugar, blood pressure, etc.).
# - **Audio:** "Your data may not be enough to diagnose you, but it's not normal either."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Shot of a person looking concerned, surrounded by medical professionals.
# - **Audio:** "Don't ignore the 'grey zone'. It could lead to serious health issues."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Close-up of the person from Scene 1, now with a determined expression.
# - **Audio:** "Take action today. Get your health checked and stay out of the 'grey zone'."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 11/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Motion graphics showcasing a person with a high BMI and sedentary lifestyle.
# - **Audio:** Narrator: "Unhealthy habits like irregular eating and lack of exercise can lead to..."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-up of an overweight person experiencing shortness of breath.
# - **Audio:** Narrator: "Serious health issues."
# - **Infographic overlay:** Statistics on the prevalence of obesity-related diseases.
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Transformation shot of the person making healthy lifestyle choices: eating a balanced diet and exercising regularly.
# - **Audio:** Narrator: "But it's not too late to make a change."
# - **Infographic overlay:** Tips for adopting healthier habits.
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Empowered individuals enjoying the benefits of a healthy lifestyle.
# - **Audio:** Narrator: "Take control of your health today."
# - **Call to action:** "Visit our website for personalized guidance and support."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 12/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Graphics of a person eating a meal, then a blood glucose monitor with high reading
# - **Audio:** "Diabetes is a serious health condition that affects millions."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Data table of research findings showing high blood glucose, blood pressure, and family history as risk factors
# - **Audio:** "Our research shows these factors can significantly increase your diabetes risk."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Person getting medical exam and monitoring
# - **Audio:** "Early detection is key. Get screened if you have risk factors."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call to action for viewers to visit a healthcare professional or website for more information
# - **Audio:** "Don't wait. Get checked today."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 13/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Animated illustration of a two-dimensional dataset with two classes, each represented by different colored points.
# - **Audio:** Narrator: "Machine learning algorithms strive to find the best way to separate different classes of data."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Zoom in on the maximum-margin hyperplane, visually separating the two classes.
# - **Audio:** Narrator: "The maximum-margin hyperplane maximizes the distance between the two classes, ensuring clear separation."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Illustration of support vectors, the data points closest to the hyperplane, highlighted as circles.
# - **Audio:** Narrator: "Support vectors define the hyperplane and play a crucial role in determining the classification boundary."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Text overlay: "Powerful Classification with Support Vector Machines."
# - **Audio:** Narrator: "Support vector machines are powerful tools for classification, enabling accurate decision-making based on complex datasets. Explore more with SVM resources."
# - **Call to Action:** Link to SVM resources or website.
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 14/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a hypercube floating in a dark void.
# - **Audio:** "In the realm of complex data, where dimensions intertwine..."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** The hypercube rotates, revealing a series of data points distributed across its surfaces.
# - **Audio:** "...data points dance, carrying insights yet unseen."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A laser beam pierces through the hypercube, creating a hyperplane that divides the data points.
# - **Audio:** "But alas, planes that divide, obscuring the true patterns hidden within."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** The hypercube transforms into a 3D cube, with the data points now clearly aligned.
# - **Audio:** "Fear not! By unraveling these geometric tapestries, we empower ourselves to unlock the secrets of data."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 15/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Animated graph with data points and a linear regression line.
# - **Audio:** **Narrator:** "Unleashing Data's Power through Statistical Modeling"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** The graph transforms, data points revealing interconnectedness.
# - **Audio:** **Narrator:** "Beyond Simple Assumptions: Real-World Complexity"
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A schematic flow diagram of probabilistic calculations.
# - **Audio:** **Narrator:** "Calculating Class Probabilities: A Surprising Tool for Success"
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** The graph and flow diagram converge into a cohesive image.
# - **Audio:** **Narrator:** "Harness the Power of Data for Informed Decision-Making. Explore Statistical Modeling Today!"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 16/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Dissolve from a complex mathematical equation (research text) to a doctor examining a patient's insulin levels.
# - **Audio:** "**Unveiling the Secrets of Diabetes Detection:** Harnessing Math for Health."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Data visualization of diabetes probability calculations using Gaussian distribution and Bayes' theorem.
# - **Audio:** "**Empowering Physicians:** Statistical models empower healthcare professionals with real-time diabetes risk predictions."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A group of doctors using AI-powered diagnostic tools to quickly assess patients.
# - **Audio:** "**Revolutionizing Patient Care:** Faster and more accurate diagnoses lead to better outcomes."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A family embracing the empowered future of healthcare.
# - **Audio:** "**Shaping a Healthier Tomorrow:** Together, we're leveraging AI to reduce diabetes prevalence and improve lives. #DiabetesDetectionSimplified"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 17/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a smartphone screen showing medical data being analyzed.
# - **Audio:** "Advanced AI is making significant strides in healthcare."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Computer-generated animation demonstrating how AI algorithms detect patterns in medical data.
# - **Audio:** "AI algorithms can identify potential health risks, like diabetes."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Split-screen showing a person struggling with diabetes symptoms vs. a healthy individual.
# - **Audio:** "Early detection is crucial for managing diabetes."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Close-up of a smartphone screen with an app that helps users monitor their health.
# - **Audio:** "Empower yourself with the latest technology. Join the movement to detect diabetes early."
# - **Call to Action:** "Download our free app now!"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 18/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Storyboard for 1-Minute Instagram Reel on Classifier Performance Evaluation**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a research scientist analyzing data on a computer screen.
# - **Audio:** Narrator voiceover: "Evaluating the performance of machine learning classifiers is crucial for ensuring accuracy."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Montage of graphs and charts illustrating different evaluation metrics (e.g., precision, recall, F1 score).
# - **Audio:** "Repeated holdout validation, a reliable method, involves running simulations 100 times to measure performance."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Scientists discussing sample size determination through statistical analysis.
# - **Audio:** "Determining the correct sample size ensures representative results within acceptable margins of error."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Application demonstration showcasing two modes: assessment and data analysis.
# - **Audio:** "Our interactive application streamlines the evaluation process, providing comprehensive insights and visualizations."
# - **Call to action:** "Visit our website for more information and to download the app."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 19/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Diabetes diagnostic application GUI (Fig. 1)
# - **Audio:** "Introducing a cutting-edge tool for diabetes detection."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** New records being added to the database
# - **Audio:** "Data acquisition mode empowers users to expand the dataset, increasing accuracy."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Assessment mode predicting diabetes status on new records
# - **Audio:** "Dual classification ensures reliability: SVM and Naïve Bayes provide consistent results."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call-to-action slide with QR code/link to download the app
# - **Audio:** "Empower yourself with knowledge. Download our app today and take control of your health."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 20/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a diabetic testing strip with a drop of blood, turning red.
# - **Audio:** Narrator: "Diabetes impacts millions of people worldwide."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Montage of people with diabetes managing their condition (e.g., taking insulin, measuring glucose levels).
# - **Audio:** Narrator: "From insulin injections to blood sugar monitoring, managing diabetes can be challenging."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Expert (e.g., doctor or researcher) discussing advances in diabetes detection and treatment.
# - **Audio:** Expert: "But there's hope. Advanced technologies are revolutionizing diabetes care."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Smartphone app or device displaying real-time glucose monitoring or early warning system.
# - **Audio:** Narrator: "With these innovations, we can empower individuals to proactively manage their diabetes and improve their health."
# - **Closing shot:** Call to action: "Together, let's make a difference in the lives of those affected by diabetes."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 21/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Table or graph showing comparison of classification performance between SVM and Naïve Bayes classifiers.
# - **Audio:** "Comparing performance of SVM and Naïve Bayes classifiers for diabetes detection."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-up of specific data point showing SVM classifier's high accuracy (95.52%).
# - **Audio:** "SVM classifier achieves an accuracy of 95.52%."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Close-up of specific data point showing Naïve Bayes classifier's slightly lower but still impressive accuracy (94.53%).
# - **Audio:** "Naïve Bayes classifier performs slightly lower at 94.53% accuracy."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call to action animation encouraging viewers to learn more about the research and its implications for diabetes detection.
# - **Audio:** "Discover how these classifiers empower us to detect diabetes more accurately. Visit our website for details."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 22/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Eye-catching animation showcasing machine learning algorithms (e.g., SVM vs. Naive Bayes) in a playful manner.
# - **Audio:** **On-screen text:** "Machine Learning Accuracy Smackdown!"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** A simple bar chart visualizing the accuracy comparison between SVM and Naive Bayes.
# - **Audio:** "In a head-to-head, SVM takes the crown for accuracy, but don't count out Naive Bayes!"
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A dynamic infographic explaining precision and recall measures using visual cues like arrows and circles.
# - **Audio:** "Let's dive deeper: Precision tells us how many predictions were actually correct, while Recall shows how well we catch everything that should have been caught!"
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A series of "before and after" animations demonstrating the impact of using better machine learning algorithms.
# - **Audio:** "The right algorithm can change the game! Improve your decision-making and embrace the power of machine learning today!"
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 23/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** A montage of people using computers and browsing the internet.
# - **Audio:** "Are you worried about online privacy?"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** A close-up shot of a smartphone with a privacy notice appearing on the screen.
# - **Audio:** "Smartphones collect a lot of data about us, which can be used to track our movements, identify our interests, and even predict our behavior."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A split-screen showing two different images: one of a secure smartphone and one of an unsecure smartphone.
# - **Audio:** "There are ways to protect your online privacy, like using strong passwords and avoiding unsecured websites."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A group of people smiling and using their smartphones confidently.
# - **Audio:** "By taking these precautions, you can protect your online privacy and enjoy the benefits of the internet without compromising your personal information."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 24/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Graphic of two doctors analyzing patient data.
# - **Audio:** "Diabetes detection is crucial, but often difficult."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Animation showing the classification process by two independent doctors.
# - **Audio:** "Traditionally, new patients are classified by individual doctors, leading to inconsistencies."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Diagram highlighting the combined decision-making approach.
# - **Audio:** "Our research combined the results of two classifiers, increasing accuracy by 2.4%."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call-to-action message "Empower yourself with accurate diabetes detection. Contact your doctor today!"
# - **Audio:** Narrator emphasizes the importance of early detection and urges viewers to take action.
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 25/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Animated graph showing rising number of undiagnosed diabetes cases.
# - **Audio:** "Diabetes detection just got easier!"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Scientists working on a new algorithm that combines SVM and Naive Bayes methods.
# - **Audio:** "We're using cutting-edge AI to revolutionize diabetes detection."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Montage of people getting diabetes screenings and receiving fast, accurate results.
# - **Audio:** "Our algorithm is highly accurate, giving you the peace of mind you deserve."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Close-up of a smartphone screen showing the diabetes detection app.
# - **Audio:** "Download our app today and take control of your health!" **(Call to action)**
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 26/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up shot of an algorithmic code running on a computer screen.
# - **Audio:** **Narrator:** "Artificial intelligence is revolutionizing healthcare."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** B-roll footage of a patient being examined by a doctor.
# - **Audio:** **Narrator:** "But all AI algorithms are not created equal. Some are more accurate than others."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Graph showing the accuracy of different AI algorithms.
# - **Audio:** **Narrator:** "Our research has shown that Algorithm X has an accuracy rate of 97.6% in detecting diabetes."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call-to-action screen with a link to the website for the diabetes detection tool.
# - **Audio:** **Narrator:** "Visit our website to learn more about Algorithm X and how it can help you detect diabetes early."
#
# 🔷 References Detected: []
#
# 🔹 Processing Chunk 27/27...
#
# ✅ 1-Minute Storyboard generated successfully.
#
# 🎬 **1-Minute Reel Storyboard:**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Microscope slides with cells and test tubes
# - **Audio:** "Precision medicine aims to tailor treatments based on individual health data."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-ups of a patient's eyes and facial expressions
# - **Audio:** "The key is to identify potential treatment responders and non-responders early on."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Animated graphs and charts showing clinical data and results
# - **Audio:** "Our research tool analyzes patient information to predict treatment performance."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Doctor discussing treatment options with a patient
# - **Audio:** "Empowering clinicians with this knowledge allows them to make personalized decisions."
# - **Call to action:** "Learn how our tool can advance precision medicine in your practice."
#
# 🔷 References Detected: []
#
# 🔷 **Final 1-Minute Reel Storyboard:**
#
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Animated infographic showing increasing numbers of people affected by diabetes
# - **Audio:** "Diabetes is on the rise, with over 346 million people worldwide"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-up of a person looking worried as they read a diabetes test result
# - **Audio:** "One-third of these cases go undetected in the early stages"
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A montage of people interacting with a diabetes prediction system
# - **Audio:** "Our intelligent system helps detect diabetes early, empowering you to make informed choices"
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Close-up of the system's logo and website address
# - **Audio:** "Visit our website [website address] to learn more and get your free screening today"
# **Scene 1 (0-15 seconds)**
# - **Visual:** A group of doctors study patient data on a computer.
# - **Audio:** "Unlocking the power of data to detect diabetes."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** A diagram shows how the algorithm analyzes data to identify patterns.
# - **Audio:** "Our algorithm uses advanced machine learning methods to sift through vast amounts of patient data."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A patient undergoes a medical examination.
# - **Audio:** "This groundbreaking technology empowers healthcare professionals to identify diabetes risk early, enabling prompt intervention."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A doctor discusses the value of the algorithm with a patient.
# - **Audio:** "Join the revolution in diabetes detection. Visit our website or consult your healthcare provider today."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of blood glucose meter displaying high reading.
# - **Audio:** "Diabetes: A silent epidemic affecting millions worldwide."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Montage of individuals experiencing diabetic complications (e.g., vision impairment, foot ulcers).
# - **Audio:** "From heart disease to blindness, diabetes takes a devastating toll on our health."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Animated infographic demonstrating how support vector machines (SVMs) can identify diabetes patterns in medical data.
# - **Audio:** "SVMs: A powerful tool for detecting diabetes early."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call to action: "Get screened today. Early detection is crucial for preventing complications."
# - **Audio:** "Join the fight against diabetes and empower your health with an SVM screening."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a person's face looking worried.
# - **Audio:** "Do you have these symptoms?"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Shots of people experiencing common diabetes symptoms: thirst, fatigue, weight loss.
# - **Audio:** Narration: "If yes, you may be at risk of prediabetes or diabetes."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Shots of healthcare professionals using computers and medical equipment.
# - **Audio:** Narration: "Machine learning algorithms can help early detection based on your data."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Patient smiling with a relieved expression.
# - **Audio:** Narration: "Get screened now. Don't wait to develop full-blown diabetes. #DiabetesDetection" (Call to action)
# **Scene 1 (0-15 seconds)**
# - **Visual:** Microscope images of pancreas cells
# - **Audio:** "Unlocking the potential of AI in diabetes detection."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Algorithms analyzing medical data
# - **Audio:** "AI algorithms can learn patterns in vast datasets, helping us identify diabetes risk."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** SVM and Naïve Bayes methods being used
# - **Audio:** "Specific machine learning methods, like SVM, excel in diabetes detection accuracy."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Real-time diabetes detection system
# - **Audio:** "With AI-powered tools, we can diagnose diabetes early and empower individuals to take preventive measures."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Graphic of two algorithms merging together, representing joint implementation.
# - **Audio:** "Introducing a breakthrough in data analysis..."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Charts and graphs showing high accuracy in data classification.
# - **Audio:** "Our research reveals the power of combining algorithms, minimizing weaknesses for better results."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Scientist working on a computer, representing experimental setup.
# - **Audio:** "This innovative approach enhances reliability, utilizing the strengths of each algorithm."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Logo and branding, accompanied by text "Learn more at [website address]".
# - **Audio:** "Unlock the potential of joint implementation for precise data analysis. Visit our website today!"
# **Scene 1 (0-15 seconds)**
# - **Visual:** A montage of medical images (X-rays, MRIs, etc.) showing people affected by heart disease, cancer, and diabetes.
# - **Audio:** Narrator: "Chronic diseases like heart disease, cancer, and diabetes affect millions worldwide."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Shots of doctors and patients using AI-powered diagnostic tools.
# - **Audio:** Narrator: "AI is revolutionizing healthcare by providing faster and more accurate detection of these diseases."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A timeline showing the decreasing cost of AI-powered diagnostic tools.
# - **Audio:** Narrator: "As AI becomes more accessible, early detection will become even more widespread."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A diverse group of people smiling and living healthier lives.
# - **Audio:** Narrator: "With AI, we can empower everyone to take control of their health and live longer, healthier lives. Join us in the fight against chronic diseases."
# **Storyboard for a 1-Minute Instagram Reel on Diabetes Detection**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a person's face, looking concerned.
# - **Audio:** Narrator: "Do you know the warning signs of diabetes?"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Montage of images showing symptoms of diabetes, such as excessive thirst, frequent urination, and unexplained weight loss.
# - **Audio:** Narrator: "Diabetes is a serious disease, affecting millions worldwide."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Person getting a blood test.
# - **Audio:** Narrator: "Early detection is crucial. Get tested to know your risk."
# - **Visual transitions:** zoom in on the blood drop on the test strip, indicating a positive result.
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** People living healthy lifestyles, such as exercising and eating healthy food.
# - **Audio:** Narrator: "Take charge of your health. Manage diabetes with lifestyle changes and medication."
# - **Call to action:** "Get tested today. Take control of your diabetes journey."
# **Storyboard for 1-Minute Instagram Reel**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Quick montage of researchers working in a lab, coding on computers, and analyzing data.
# - **Audio:** "Unlocking the power of data for diabetes detection..."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-up of a person taking a blood test. Focus on the data being collected and analyzed.
# - **Audio:** "Traditional methods can be limited, but new algorithms are changing the game."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Animated diagram showing how hybrid algorithms combine distance-based and statistical methods to improve accuracy.
# - **Audio:** "By combining different approaches, we can create more precise and reliable results."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Data being analyzed and interpreted. Focus on the practical applications of these algorithms in healthcare settings.
# - **Audio:** "Empowering medical professionals with cutting-edge tools to improve diabetes detection. Let's join forces against diabetes!"
# **Call to action:** "Find out more at [website address]."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a person's face, with a question mark on their forehead.
# - **Audio:** "Are you in the 'grey zone' when it comes to health?"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Panning shot of medical data (e.g., blood sugar, blood pressure, etc.).
# - **Audio:** "Your data may not be enough to diagnose you, but it's not normal either."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Shot of a person looking concerned, surrounded by medical professionals.
# - **Audio:** "Don't ignore the 'grey zone'. It could lead to serious health issues."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Close-up of the person from Scene 1, now with a determined expression.
# - **Audio:** "Take action today. Get your health checked and stay out of the 'grey zone'."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Motion graphics showcasing a person with a high BMI and sedentary lifestyle.
# - **Audio:** Narrator: "Unhealthy habits like irregular eating and lack of exercise can lead to..."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-up of an overweight person experiencing shortness of breath.
# - **Audio:** Narrator: "Serious health issues."
# - **Infographic overlay:** Statistics on the prevalence of obesity-related diseases.
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Transformation shot of the person making healthy lifestyle choices: eating a balanced diet and exercising regularly.
# - **Audio:** Narrator: "But it's not too late to make a change."
# - **Infographic overlay:** Tips for adopting healthier habits.
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Empowered individuals enjoying the benefits of a healthy lifestyle.
# - **Audio:** Narrator: "Take control of your health today."
# - **Call to action:** "Visit our website for personalized guidance and support."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Graphics of a person eating a meal, then a blood glucose monitor with high reading
# - **Audio:** "Diabetes is a serious health condition that affects millions."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Data table of research findings showing high blood glucose, blood pressure, and family history as risk factors
# - **Audio:** "Our research shows these factors can significantly increase your diabetes risk."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Person getting medical exam and monitoring
# - **Audio:** "Early detection is key. Get screened if you have risk factors."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call to action for viewers to visit a healthcare professional or website for more information
# - **Audio:** "Don't wait. Get checked today."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Animated illustration of a two-dimensional dataset with two classes, each represented by different colored points.
# - **Audio:** Narrator: "Machine learning algorithms strive to find the best way to separate different classes of data."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Zoom in on the maximum-margin hyperplane, visually separating the two classes.
# - **Audio:** Narrator: "The maximum-margin hyperplane maximizes the distance between the two classes, ensuring clear separation."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Illustration of support vectors, the data points closest to the hyperplane, highlighted as circles.
# - **Audio:** Narrator: "Support vectors define the hyperplane and play a crucial role in determining the classification boundary."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Text overlay: "Powerful Classification with Support Vector Machines."
# - **Audio:** Narrator: "Support vector machines are powerful tools for classification, enabling accurate decision-making based on complex datasets. Explore more with SVM resources."
# - **Call to Action:** Link to SVM resources or website.
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a hypercube floating in a dark void.
# - **Audio:** "In the realm of complex data, where dimensions intertwine..."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** The hypercube rotates, revealing a series of data points distributed across its surfaces.
# - **Audio:** "...data points dance, carrying insights yet unseen."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A laser beam pierces through the hypercube, creating a hyperplane that divides the data points.
# - **Audio:** "But alas, planes that divide, obscuring the true patterns hidden within."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** The hypercube transforms into a 3D cube, with the data points now clearly aligned.
# - **Audio:** "Fear not! By unraveling these geometric tapestries, we empower ourselves to unlock the secrets of data."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Animated graph with data points and a linear regression line.
# - **Audio:** **Narrator:** "Unleashing Data's Power through Statistical Modeling"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** The graph transforms, data points revealing interconnectedness.
# - **Audio:** **Narrator:** "Beyond Simple Assumptions: Real-World Complexity"
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A schematic flow diagram of probabilistic calculations.
# - **Audio:** **Narrator:** "Calculating Class Probabilities: A Surprising Tool for Success"
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** The graph and flow diagram converge into a cohesive image.
# - **Audio:** **Narrator:** "Harness the Power of Data for Informed Decision-Making. Explore Statistical Modeling Today!"
# **Scene 1 (0-15 seconds)**
# - **Visual:** Dissolve from a complex mathematical equation (research text) to a doctor examining a patient's insulin levels.
# - **Audio:** "**Unveiling the Secrets of Diabetes Detection:** Harnessing Math for Health."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Data visualization of diabetes probability calculations using Gaussian distribution and Bayes' theorem.
# - **Audio:** "**Empowering Physicians:** Statistical models empower healthcare professionals with real-time diabetes risk predictions."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A group of doctors using AI-powered diagnostic tools to quickly assess patients.
# - **Audio:** "**Revolutionizing Patient Care:** Faster and more accurate diagnoses lead to better outcomes."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A family embracing the empowered future of healthcare.
# - **Audio:** "**Shaping a Healthier Tomorrow:** Together, we're leveraging AI to reduce diabetes prevalence and improve lives. #DiabetesDetectionSimplified"
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a smartphone screen showing medical data being analyzed.
# - **Audio:** "Advanced AI is making significant strides in healthcare."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Computer-generated animation demonstrating how AI algorithms detect patterns in medical data.
# - **Audio:** "AI algorithms can identify potential health risks, like diabetes."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Split-screen showing a person struggling with diabetes symptoms vs. a healthy individual.
# - **Audio:** "Early detection is crucial for managing diabetes."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Close-up of a smartphone screen with an app that helps users monitor their health.
# - **Audio:** "Empower yourself with the latest technology. Join the movement to detect diabetes early."
# - **Call to Action:** "Download our free app now!"
# **Storyboard for 1-Minute Instagram Reel on Classifier Performance Evaluation**
#
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a research scientist analyzing data on a computer screen.
# - **Audio:** Narrator voiceover: "Evaluating the performance of machine learning classifiers is crucial for ensuring accuracy."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Montage of graphs and charts illustrating different evaluation metrics (e.g., precision, recall, F1 score).
# - **Audio:** "Repeated holdout validation, a reliable method, involves running simulations 100 times to measure performance."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Scientists discussing sample size determination through statistical analysis.
# - **Audio:** "Determining the correct sample size ensures representative results within acceptable margins of error."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Application demonstration showcasing two modes: assessment and data analysis.
# - **Audio:** "Our interactive application streamlines the evaluation process, providing comprehensive insights and visualizations."
# - **Call to action:** "Visit our website for more information and to download the app."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Diabetes diagnostic application GUI (Fig. 1)
# - **Audio:** "Introducing a cutting-edge tool for diabetes detection."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** New records being added to the database
# - **Audio:** "Data acquisition mode empowers users to expand the dataset, increasing accuracy."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Assessment mode predicting diabetes status on new records
# - **Audio:** "Dual classification ensures reliability: SVM and Naïve Bayes provide consistent results."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call-to-action slide with QR code/link to download the app
# - **Audio:** "Empower yourself with knowledge. Download our app today and take control of your health."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up of a diabetic testing strip with a drop of blood, turning red.
# - **Audio:** Narrator: "Diabetes impacts millions of people worldwide."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Montage of people with diabetes managing their condition (e.g., taking insulin, measuring glucose levels).
# - **Audio:** Narrator: "From insulin injections to blood sugar monitoring, managing diabetes can be challenging."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Expert (e.g., doctor or researcher) discussing advances in diabetes detection and treatment.
# - **Audio:** Expert: "But there's hope. Advanced technologies are revolutionizing diabetes care."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Smartphone app or device displaying real-time glucose monitoring or early warning system.
# - **Audio:** Narrator: "With these innovations, we can empower individuals to proactively manage their diabetes and improve their health."
# - **Closing shot:** Call to action: "Together, let's make a difference in the lives of those affected by diabetes."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Table or graph showing comparison of classification performance between SVM and Naïve Bayes classifiers.
# - **Audio:** "Comparing performance of SVM and Naïve Bayes classifiers for diabetes detection."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-up of specific data point showing SVM classifier's high accuracy (95.52%).
# - **Audio:** "SVM classifier achieves an accuracy of 95.52%."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Close-up of specific data point showing Naïve Bayes classifier's slightly lower but still impressive accuracy (94.53%).
# - **Audio:** "Naïve Bayes classifier performs slightly lower at 94.53% accuracy."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call to action animation encouraging viewers to learn more about the research and its implications for diabetes detection.
# - **Audio:** "Discover how these classifiers empower us to detect diabetes more accurately. Visit our website for details."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Eye-catching animation showcasing machine learning algorithms (e.g., SVM vs. Naive Bayes) in a playful manner.
# - **Audio:** **On-screen text:** "Machine Learning Accuracy Smackdown!"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** A simple bar chart visualizing the accuracy comparison between SVM and Naive Bayes.
# - **Audio:** "In a head-to-head, SVM takes the crown for accuracy, but don't count out Naive Bayes!"
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A dynamic infographic explaining precision and recall measures using visual cues like arrows and circles.
# - **Audio:** "Let's dive deeper: Precision tells us how many predictions were actually correct, while Recall shows how well we catch everything that should have been caught!"
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A series of "before and after" animations demonstrating the impact of using better machine learning algorithms.
# - **Audio:** "The right algorithm can change the game! Improve your decision-making and embrace the power of machine learning today!"
# **Scene 1 (0-15 seconds)**
# - **Visual:** A montage of people using computers and browsing the internet.
# - **Audio:** "Are you worried about online privacy?"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** A close-up shot of a smartphone with a privacy notice appearing on the screen.
# - **Audio:** "Smartphones collect a lot of data about us, which can be used to track our movements, identify our interests, and even predict our behavior."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** A split-screen showing two different images: one of a secure smartphone and one of an unsecure smartphone.
# - **Audio:** "There are ways to protect your online privacy, like using strong passwords and avoiding unsecured websites."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** A group of people smiling and using their smartphones confidently.
# - **Audio:** "By taking these precautions, you can protect your online privacy and enjoy the benefits of the internet without compromising your personal information."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Graphic of two doctors analyzing patient data.
# - **Audio:** "Diabetes detection is crucial, but often difficult."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Animation showing the classification process by two independent doctors.
# - **Audio:** "Traditionally, new patients are classified by individual doctors, leading to inconsistencies."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Diagram highlighting the combined decision-making approach.
# - **Audio:** "Our research combined the results of two classifiers, increasing accuracy by 2.4%."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call-to-action message "Empower yourself with accurate diabetes detection. Contact your doctor today!"
# - **Audio:** Narrator emphasizes the importance of early detection and urges viewers to take action.
# **Scene 1 (0-15 seconds)**
# - **Visual:** Animated graph showing rising number of undiagnosed diabetes cases.
# - **Audio:** "Diabetes detection just got easier!"
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Scientists working on a new algorithm that combines SVM and Naive Bayes methods.
# - **Audio:** "We're using cutting-edge AI to revolutionize diabetes detection."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Montage of people getting diabetes screenings and receiving fast, accurate results.
# - **Audio:** "Our algorithm is highly accurate, giving you the peace of mind you deserve."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Close-up of a smartphone screen showing the diabetes detection app.
# - **Audio:** "Download our app today and take control of your health!" **(Call to action)**
# **Scene 1 (0-15 seconds)**
# - **Visual:** Close-up shot of an algorithmic code running on a computer screen.
# - **Audio:** **Narrator:** "Artificial intelligence is revolutionizing healthcare."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** B-roll footage of a patient being examined by a doctor.
# - **Audio:** **Narrator:** "But all AI algorithms are not created equal. Some are more accurate than others."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Graph showing the accuracy of different AI algorithms.
# - **Audio:** **Narrator:** "Our research has shown that Algorithm X has an accuracy rate of 97.6% in detecting diabetes."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Call-to-action screen with a link to the website for the diabetes detection tool.
# - **Audio:** **Narrator:** "Visit our website to learn more about Algorithm X and how it can help you detect diabetes early."
# **Scene 1 (0-15 seconds)**
# - **Visual:** Microscope slides with cells and test tubes
# - **Audio:** "Precision medicine aims to tailor treatments based on individual health data."
#
# **Scene 2 (15-30 seconds)**
# - **Visual:** Close-ups of a patient's eyes and facial expressions
# - **Audio:** "The key is to identify potential treatment responders and non-responders early on."
#
# **Scene 3 (30-45 seconds)**
# - **Visual:** Animated graphs and charts showing clinical data and results
# - **Audio:** "Our research tool analyzes patient information to predict treatment performance."
#
# **Scene 4 (45-60 seconds)**
# - **Visual:** Doctor discussing treatment options with a patient
# - **Audio:** "Empowering clinicians with this knowledge allows them to make personalized decisions."
# - **Call to action:** "Learn how our tool can advance precision medicine in your practice."
